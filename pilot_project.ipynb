# %% [markdown]
# # AIDR Final Project - Pilot project

# %% [markdown]
# The scope of this notebook is to offer an example of the end to end implementation of the final project. Some tips:
# * use shift+enter to run each cell
# * use ctrl+alt+o to optimize your imports
# * use ctrl+alt+l to arrange your code
# * ctrl+click on the name of a variable/library will take you to it
# * the easiest way to install a library is by going to Interpreter Settings -> Install (ctrl+alt+s to access Settings)
# * use ctrl+k to commit and select the file(s) you want to commit
# * use the number (#123456) of the corresponding GitHub issue in your commit message to link your commit to the issue
# * use ctrl+shift+k to push your commits

# %% [markdown]
# ### Project setup

# %%
import numpy as np
import pandas as pd
import requests
import seaborn as sns
from pymongo import MongoClient
from unidecode import unidecode

sns.set(style='whitegrid', palette='pastel', color_codes=True)
sns.mpl.rc('figure', figsize=(20, 20))
% matplotlib inline

# %% [markdown]
# ### Data gathering

# %%
# Data gathering from files published on different platforms
url = "https://raw.githubusercontent.com/stefanacioban/covid_19_spatial_analysis/main/data/hindex_interpolated.csv"
lhdi = pd.read_csv(url)

# %%
lhdi.head()
# Out:
#      siruta  lhdi_2018_pred
# 0  153400.0            41.0
# 1  152314.0            40.0
# 2  151978.0            57.8
# 3  151709.0            39.9
# 4  155118.0            50.0

# %% [markdown]
# This dataset contains the Local Human Development Index for each Administrative Territorial Unit (ATU) in Romania ([Sandu, 2020](https://www.sciencedirect.com/science/article/pii/S221167532100066X?via%3Dihub#b25)). The index was predicted for all ATUs with a population of less than 1000 inhabitants using spatial interpolation methods. The SIRUTA code is a unique identifier for each ATU.

# %%
# Check the data types of each column
lhdi.dtypes
# Out:
# siruta            float64
# lhdi_2018_pred    float64
# dtype: object

# %%
# Store the csv locally to further import it to the Database
lhdi.to_csv("data/lhdi.csv", index=False)

# %% [markdown]
# Once this dataset was locally stored, create a new MongoDB collection and import it over there.
# All intermediary csv files will have to be committed to GitHub with your code.

# %% [markdown]
# ### Database connection

# %%
# uri (uniform resource identifier) defines the connection parameters
uri = 'mongodb://localhost:27017'

# %%
client = MongoClient(uri)
client.list_database_names()  # list the database names
# Out:
# ['admin', 'config', 'local']

# %%
db = client.local
db
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'local')

# %%
# Check out the collections names from the local database
list(db.list_collections())
# Out:
# [{'name': 'lhdi_2018_pred',
#   'type': 'collection',
#   'options': {},
#   'info': {'readOnly': False,
#    'uuid': UUID('2900128c-4a30-4b51-99fa-36b9ce3b7d79')},
#   'idIndex': {'v': 2, 'key': {'_id': 1}, 'name': '_id_'}},
#  {'name': 'siruta',
#   'type': 'collection',
#   'options': {},
#   'info': {'readOnly': False,
#    'uuid': UUID('99c43a2f-f4de-4df2-b2a3-debf844e965e')},
#   'idIndex': {'v': 2, 'key': {'_id': 1}, 'name': '_id_'}},
#  {'name': 'startup_log',
#   'type': 'collection',
#   'options': {'capped': True, 'size': 10485760},
#   'info': {'readOnly': False,
#    'uuid': UUID('cc78fd48-5327-4eda-9efa-6913d2e6468e')},
#   'idIndex': {'v': 2, 'key': {'_id': 1}, 'name': '_id_'}}]

# %%
# Create a cursor using a filter
# The {'lhdi_2018_pred': 40} filter is equivalent to SELECT * FROM local.lhdi_2018_pred WHERE lhdi_2018_pred=40
cursor = db.lhdi_2018_pred.find({'lhdi_2018_pred': 40})
for item in cursor:
    print(item)
# Out:
# {'_id': ObjectId('61d20d53d9221e342731f9ce'), 'siruta': 152314, 'lhdi_2018_pred': 40}
# {'_id': ObjectId('61d20d53d9221e342731fc77'), 'siruta': 69447, 'lhdi_2018_pred': 40}
# {'_id': ObjectId('61d20d53d9221e342731feda'), 'siruta': 86222, 'lhdi_2018_pred': 40}
# {'_id': ObjectId('61d20d53d9221e342731ffe5'), 'siruta': 25291, 'lhdi_2018_pred': 40}
# {'_id': ObjectId('61d20d53d9221e3427320374'), 'siruta': 93487, 'lhdi_2018_pred': 40}
# {'_id': ObjectId('61d20d53d9221e342732040c'), 'siruta': 154497, 'lhdi_2018_pred': 40}

# %%
# The {} filter is equivalent to SELECT * FROM local.lhdi_2018_pred
cursor = db.lhdi_2018_pred.find({})
for item in cursor:
    print(item)
# Out:
# {'_id': ObjectId('61d20d53d9221e342731f9cd'), 'siruta': 153400, 'lhdi_2018_pred': 41}
# {'_id': ObjectId('61d20d53d9221e342731f9ce'), 'siruta': 152314, 'lhdi_2018_pred': 40}
# {'_id': ObjectId('61d20d53d9221e342731f9cf'), 'siruta': 151978, 'lhdi_2018_pred': 57.8}
# {'_id': ObjectId('61d20d53d9221e342731f9d0'), 'siruta': 151709, 'lhdi_2018_pred': 39.9}
# {'_id': ObjectId('61d20d53d9221e342731f9d1'), 'siruta': 155118, 'lhdi_2018_pred': 50}
# {'_id': ObjectId('61d20d53d9221e342731f9d2'), 'siruta': 151736, 'lhdi_2018_pred': 42.3}
# {'_id': ObjectId('61d20d53d9221e342731f9d3'), 'siruta': 125588, 'lhdi_2018_pred': 43.5}
# {'_id': ObjectId('61d20d53d9221e342731f9d4'), 'siruta': 152234, 'lhdi_2018_pred': 47.3}
# {'_id': ObjectId('61d20d53d9221e342731f9d5'), 'siruta': 127938, 'lhdi_2018_pred': 50.7}
# {'_id': ObjectId('61d20d53d9221e342731f9d6'), 'siruta': 70879, 'lhdi_2018_pred': 45.5}
# {'_id': ObjectId('61d20d53d9221e342731f9d7'), 'siruta': 103194, 'lhdi_2018_pred': 46.4}
# {'_id': ObjectId('61d20d53d9221e342731f9d8'), 'siruta': 127251, 'lhdi_2018_pred': 44.9}
# {'_id': ObjectId('61d20d53d9221e342731f9d9'), 'siruta': 130339, 'lhdi_2018_pred': 52.2}
# {'_id': ObjectId('61d20d53d9221e342731f9da'), 'siruta': 153589, 'lhdi_2018_pred': 42.6}
# {'_id': ObjectId('61d20d53d9221e342731f9db'), 'siruta': 154460, 'lhdi_2018_pred': 48.6}
# {'_id': ObjectId('61d20d53d9221e342731f9dc'), 'siruta': 127224, 'lhdi_2018_pred': 43}
# {'_id': ObjectId('61d20d53d9221e342731f9dd'), 'siruta': 105909, 'lhdi_2018_pred': 43.5}
# {'_id': ObjectId('61d20d53d9221e342731f9de'), 'siruta': 129282, 'lhdi_2018_pred': 48.4}
# {'_id': ObjectId('61d20d53d9221e342731f9df'), 'siruta': 127368, 'lhdi_2018_pred': 54.5}
# {'_id': ObjectId('61d20d53d9221e342731f9e0'), 'siruta': 125542, 'lhdi_2018_pred': 58.5}
# {'_id': ObjectId('61d20d53d9221e342731f9e1'), 'siruta': 71607, 'lhdi_2018_pred': 49.4}
# {'_id': ObjectId('61d20d53d9221e342731f9e2'), 'siruta': 152500, 'lhdi_2018_pred': 39.6}
# {'_id': ObjectId('61d20d53d9221e342731f9e3'), 'siruta': 179739, 'lhdi_2018_pred': 53.2}
# {'_id': ObjectId('61d20d53d9221e342731f9e4'), 'siruta': 129745, 'lhdi_2018_pred': 46.8}
# {'_id': ObjectId('61d20d53d9221e342731f9e5'), 'siruta': 129629, 'lhdi_2018_pred': 49.1}
# {'_id': ObjectId('61d20d53d9221e342731f9e6'), 'siruta': 129718, 'lhdi_2018_pred': 52.9}
# {'_id': ObjectId('61d20d53d9221e342731f9e7'), 'siruta': 153561, 'lhdi_2018_pred': 43.7}
# {'_id': ObjectId('61d20d53d9221e342731f9e8'), 'siruta': 100549, 'lhdi_2018_pred': 51.9}
# {'_id': ObjectId('61d20d53d9221e342731f9e9'), 'siruta': 129460, 'lhdi_2018_pred': 46}
# {'_id': ObjectId('61d20d53d9221e342731f9ea'), 'siruta': 129898, 'lhdi_2018_pred': 50.2}
# {'_id': ObjectId('61d20d53d9221e342731f9eb'), 'siruta': 130375, 'lhdi_2018_pred': 47.7}
# {'_id': ObjectId('61d20d53d9221e342731f9ec'), 'siruta': 152662, 'lhdi_2018_pred': 33.8}
# {'_id': ObjectId('61d20d53d9221e342731f9ed'), 'siruta': 74867, 'lhdi_2018_pred': 45.6}
# {'_id': ObjectId('61d20d53d9221e342731f9ee'), 'siruta': 72463, 'lhdi_2018_pred': 43.2}
# {'_id': ObjectId('61d20d53d9221e342731f9ef'), 'siruta': 72980, 'lhdi_2018_pred': 46.4}
# {'_id': ObjectId('61d20d53d9221e342731f9f0'), 'siruta': 72034, 'lhdi_2018_pred': 51}
# {'_id': ObjectId('61d20d53d9221e342731f9f1'), 'siruta': 126148, 'lhdi_2018_pred': 50.6}
# {'_id': ObjectId('61d20d53d9221e342731f9f2'), 'siruta': 127750, 'lhdi_2018_pred': 42.1}
# {'_id': ObjectId('61d20d53d9221e342731f9f3'), 'siruta': 73996, 'lhdi_2018_pred': 33.4}
# {'_id': ObjectId('61d20d53d9221e342731f9f4'), 'siruta': 72579, 'lhdi_2018_pred': 37.6}
# {'_id': ObjectId('61d20d53d9221e342731f9f5'), 'siruta': 103309, 'lhdi_2018_pred': 27.8}
# {'_id': ObjectId('61d20d53d9221e342731f9f6'), 'siruta': 125962, 'lhdi_2018_pred': 45.5}
# {'_id': ObjectId('61d20d53d9221e342731f9f7'), 'siruta': 70897, 'lhdi_2018_pred': 38.5}
# {'_id': ObjectId('61d20d53d9221e342731f9f8'), 'siruta': 73460, 'lhdi_2018_pred': 32.8}
# {'_id': ObjectId('61d20d53d9221e342731f9f9'), 'siruta': 128588, 'lhdi_2018_pred': 47.5}
# {'_id': ObjectId('61d20d53d9221e342731f9fa'), 'siruta': 126077, 'lhdi_2018_pred': 52.8}
# {'_id': ObjectId('61d20d53d9221e342731f9fb'), 'siruta': 72640, 'lhdi_2018_pred': 46.6}
# {'_id': ObjectId('61d20d53d9221e342731f9fc'), 'siruta': 74842, 'lhdi_2018_pred': 32}
# {'_id': ObjectId('61d20d53d9221e342731f9fd'), 'siruta': 154344, 'lhdi_2018_pred': 35.1}
# {'_id': ObjectId('61d20d53d9221e342731f9fe'), 'siruta': 104715, 'lhdi_2018_pred': 44.4}
# {'_id': ObjectId('61d20d53d9221e342731f9ff'), 'siruta': 71858, 'lhdi_2018_pred': 51.2}
# {'_id': ObjectId('61d20d53d9221e342731fa00'), 'siruta': 74108, 'lhdi_2018_pred': 47}
# {'_id': ObjectId('61d20d53d9221e342731fa01'), 'siruta': 130320, 'lhdi_2018_pred': 53.3}
# {'_id': ObjectId('61d20d53d9221e342731fa02'), 'siruta': 129184, 'lhdi_2018_pred': 49.9}
# {'_id': ObjectId('61d20d53d9221e342731fa03'), 'siruta': 104519, 'lhdi_2018_pred': 38.2}
# {'_id': ObjectId('61d20d53d9221e342731fa04'), 'siruta': 71956, 'lhdi_2018_pred': 38.6}
# {'_id': ObjectId('61d20d53d9221e342731fa05'), 'siruta': 74883, 'lhdi_2018_pred': 46.5}
# {'_id': ObjectId('61d20d53d9221e342731fa06'), 'siruta': 128560, 'lhdi_2018_pred': 43.5}
# {'_id': ObjectId('61d20d53d9221e342731fa07'), 'siruta': 70940, 'lhdi_2018_pred': 45}
# {'_id': ObjectId('61d20d53d9221e342731fa08'), 'siruta': 73736, 'lhdi_2018_pred': 53.1}
# {'_id': ObjectId('61d20d53d9221e342731fa09'), 'siruta': 128613, 'lhdi_2018_pred': 41.7}
# {'_id': ObjectId('61d20d53d9221e342731fa0a'), 'siruta': 70673, 'lhdi_2018_pred': 50.8}
# {'_id': ObjectId('61d20d53d9221e342731fa0b'), 'siruta': 151816, 'lhdi_2018_pred': 51.6}
# {'_id': ObjectId('61d20d53d9221e342731fa0c'), 'siruta': 153909, 'lhdi_2018_pred': 34.5098685272}
# {'_id': ObjectId('61d20d53d9221e342731fa0d'), 'siruta': 72098, 'lhdi_2018_pred': 43.1}
# {'_id': ObjectId('61d20d53d9221e342731fa0e'), 'siruta': 130026, 'lhdi_2018_pred': 45.6}
# {'_id': ObjectId('61d20d53d9221e342731fa0f'), 'siruta': 152332, 'lhdi_2018_pred': 33.4}
# {'_id': ObjectId('61d20d53d9221e342731fa10'), 'siruta': 74581, 'lhdi_2018_pred': 39.7}
# {'_id': ObjectId('61d20d53d9221e342731fa11'), 'siruta': 129567, 'lhdi_2018_pred': 37.4}
# {'_id': ObjectId('61d20d53d9221e342731fa12'), 'siruta': 103354, 'lhdi_2018_pred': 42.5}
# {'_id': ObjectId('61d20d53d9221e342731fa13'), 'siruta': 151790, 'lhdi_2018_pred': 65}
# {'_id': ObjectId('61d20d53d9221e342731fa14'), 'siruta': 125659, 'lhdi_2018_pred': 47.7}
# {'_id': ObjectId('61d20d53d9221e342731fa15'), 'siruta': 153776, 'lhdi_2018_pred': 35.8}
# {'_id': ObjectId('61d20d53d9221e342731fa16'), 'siruta': 70352, 'lhdi_2018_pred': 53.6}
# {'_id': ObjectId('61d20d53d9221e342731fa17'), 'siruta': 74554, 'lhdi_2018_pred': 38.4}
# {'_id': ObjectId('61d20d53d9221e342731fa18'), 'siruta': 70520, 'lhdi_2018_pred': 46.6}
# {'_id': ObjectId('61d20d53d9221e342731fa19'), 'siruta': 154996, 'lhdi_2018_pred': 24.7}
# {'_id': ObjectId('61d20d53d9221e342731fa1a'), 'siruta': 102446, 'lhdi_2018_pred': 44.2}
# {'_id': ObjectId('61d20d53d9221e342731fa1b'), 'siruta': 72533, 'lhdi_2018_pred': 43.7}
# {'_id': ObjectId('61d20d53d9221e342731fa1c'), 'siruta': 74224, 'lhdi_2018_pred': 47.1}
# {'_id': ObjectId('61d20d53d9221e342731fa1d'), 'siruta': 70316, 'lhdi_2018_pred': 48.1}
# {'_id': ObjectId('61d20d53d9221e342731fa1e'), 'siruta': 126647, 'lhdi_2018_pred': 50.8}
# {'_id': ObjectId('61d20d53d9221e342731fa1f'), 'siruta': 129040, 'lhdi_2018_pred': 30.3}
# {'_id': ObjectId('61d20d53d9221e342731fa20'), 'siruta': 153204, 'lhdi_2018_pred': 31.3}
# {'_id': ObjectId('61d20d53d9221e342731fa21'), 'siruta': 127144, 'lhdi_2018_pred': 46.4}
# {'_id': ObjectId('61d20d53d9221e342731fa22'), 'siruta': 128524, 'lhdi_2018_pred': 47.2}
# {'_id': ObjectId('61d20d53d9221e342731fa23'), 'siruta': 73031, 'lhdi_2018_pred': 48.8}
# {'_id': ObjectId('61d20d53d9221e342731fa24'), 'siruta': 101001, 'lhdi_2018_pred': 37.9}
# {'_id': ObjectId('61d20d53d9221e342731fa25'), 'siruta': 71698, 'lhdi_2018_pred': 39.5}
# {'_id': ObjectId('61d20d53d9221e342731fa26'), 'siruta': 71634, 'lhdi_2018_pred': 41.4}
# {'_id': ObjectId('61d20d53d9221e342731fa27'), 'siruta': 71812, 'lhdi_2018_pred': 46.1}
# {'_id': ObjectId('61d20d53d9221e342731fa28'), 'siruta': 103899, 'lhdi_2018_pred': 19.4}
# {'_id': ObjectId('61d20d53d9221e342731fa29'), 'siruta': 74891, 'lhdi_2018_pred': 46.2}
# {'_id': ObjectId('61d20d53d9221e342731fa2a'), 'siruta': 72221, 'lhdi_2018_pred': 41.9}
# {'_id': ObjectId('61d20d53d9221e342731fa2b'), 'siruta': 129095, 'lhdi_2018_pred': 46}
# {'_id': ObjectId('61d20d53d9221e342731fa2c'), 'siruta': 70726, 'lhdi_2018_pred': 39.8}
# {'_id': ObjectId('61d20d53d9221e342731fa2d'), 'siruta': 72383, 'lhdi_2018_pred': 43.9}
# {'_id': ObjectId('61d20d53d9221e342731fa2e'), 'siruta': 73335, 'lhdi_2018_pred': 43.9}
# {'_id': ObjectId('61d20d53d9221e342731fa2f'), 'siruta': 127536, 'lhdi_2018_pred': 44.5}
# {'_id': ObjectId('61d20d53d9221e342731fa30'), 'siruta': 103470, 'lhdi_2018_pred': 42.9}
# {'_id': ObjectId('61d20d53d9221e342731fa31'), 'siruta': 125472, 'lhdi_2018_pred': 63.7}
# {'_id': ObjectId('61d20d53d9221e342731fa32'), 'siruta': 70502, 'lhdi_2018_pred': 48.4}
# {'_id': ObjectId('61d20d53d9221e342731fa33'), 'siruta': 126585, 'lhdi_2018_pred': 33.3}
# {'_id': ObjectId('61d20d53d9221e342731fa34'), 'siruta': 101724, 'lhdi_2018_pred': 40.4}
# {'_id': ObjectId('61d20d53d9221e342731fa35'), 'siruta': 125490, 'lhdi_2018_pred': 46}
# {'_id': ObjectId('61d20d53d9221e342731fa36'), 'siruta': 128472, 'lhdi_2018_pred': 38.2}
# {'_id': ObjectId('61d20d53d9221e342731fa37'), 'siruta': 104118, 'lhdi_2018_pred': 39.2}
# {'_id': ObjectId('61d20d53d9221e342731fa38'), 'siruta': 152038, 'lhdi_2018_pred': 23.4}
# {'_id': ObjectId('61d20d53d9221e342731fa39'), 'siruta': 101804, 'lhdi_2018_pred': 50.4999999952}
# {'_id': ObjectId('61d20d53d9221e342731fa3a'), 'siruta': 71787, 'lhdi_2018_pred': 43.9}
# {'_id': ObjectId('61d20d53d9221e342731fa3b'), 'siruta': 72052, 'lhdi_2018_pred': 35.5}
# {'_id': ObjectId('61d20d53d9221e342731fa3c'), 'siruta': 153865, 'lhdi_2018_pred': 25.7}
# {'_id': ObjectId('61d20d53d9221e342731fa3d'), 'siruta': 100610, 'lhdi_2018_pred': 55}
# {'_id': ObjectId('61d20d53d9221e342731fa3e'), 'siruta': 153507, 'lhdi_2018_pred': 29.3}
# {'_id': ObjectId('61d20d53d9221e342731fa3f'), 'siruta': 105348, 'lhdi_2018_pred': 35.2}
# {'_id': ObjectId('61d20d53d9221e342731fa40'), 'siruta': 128864, 'lhdi_2018_pred': 34.6}
# {'_id': ObjectId('61d20d53d9221e342731fa41'), 'siruta': 113493, 'lhdi_2018_pred': 34}
# {'_id': ObjectId('61d20d53d9221e342731fa42'), 'siruta': 179766, 'lhdi_2018_pred': 46.6}
# {'_id': ObjectId('61d20d53d9221e342731fa43'), 'siruta': 103639, 'lhdi_2018_pred': 47.9}
# {'_id': ObjectId('61d20d53d9221e342731fa44'), 'siruta': 152172, 'lhdi_2018_pred': 34.6}
# {'_id': ObjectId('61d20d53d9221e342731fa45'), 'siruta': 72882, 'lhdi_2018_pred': 42.1}
# {'_id': ObjectId('61d20d53d9221e342731fa46'), 'siruta': 126718, 'lhdi_2018_pred': 41.1}
# {'_id': ObjectId('61d20d53d9221e342731fa47'), 'siruta': 104975, 'lhdi_2018_pred': 29}
# {'_id': ObjectId('61d20d53d9221e342731fa48'), 'siruta': 154415, 'lhdi_2018_pred': 43.4}
# {'_id': ObjectId('61d20d53d9221e342731fa49'), 'siruta': 72506, 'lhdi_2018_pred': 46.6}
# {'_id': ObjectId('61d20d53d9221e342731fa4a'), 'siruta': 103372, 'lhdi_2018_pred': 40.5}
# {'_id': ObjectId('61d20d53d9221e342731fa4b'), 'siruta': 73594, 'lhdi_2018_pred': 42}
# {'_id': ObjectId('61d20d53d9221e342731fa4c'), 'siruta': 71457, 'lhdi_2018_pred': 25.4}
# {'_id': ObjectId('61d20d53d9221e342731fa4d'), 'siruta': 154166, 'lhdi_2018_pred': 45.9}
# {'_id': ObjectId('61d20d53d9221e342731fa4e'), 'siruta': 74322, 'lhdi_2018_pred': 42.4}
# {'_id': ObjectId('61d20d53d9221e342731fa4f'), 'siruta': 126102, 'lhdi_2018_pred': 40.8}
# {'_id': ObjectId('61d20d53d9221e342731fa50'), 'siruta': 112744, 'lhdi_2018_pred': 38.7}
# {'_id': ObjectId('61d20d53d9221e342731fa51'), 'siruta': 71518, 'lhdi_2018_pred': 31.6}
# {'_id': ObjectId('61d20d53d9221e342731fa52'), 'siruta': 125622, 'lhdi_2018_pred': 53.7}
# {'_id': ObjectId('61d20d53d9221e342731fa53'), 'siruta': 153473, 'lhdi_2018_pred': 37}
# {'_id': ObjectId('61d20d53d9221e342731fa54'), 'siruta': 101662, 'lhdi_2018_pred': 45.2}
# {'_id': ObjectId('61d20d53d9221e342731fa55'), 'siruta': 105259, 'lhdi_2018_pred': 34.3}
# {'_id': ObjectId('61d20d53d9221e342731fa56'), 'siruta': 74915, 'lhdi_2018_pred': 52.5}
# {'_id': ObjectId('61d20d53d9221e342731fa57'), 'siruta': 180055, 'lhdi_2018_pred': 46}
# {'_id': ObjectId('61d20d53d9221e342731fa58'), 'siruta': 62486, 'lhdi_2018_pred': 44}
# {'_id': ObjectId('61d20d53d9221e342731fa59'), 'siruta': 104751, 'lhdi_2018_pred': 39.5}
# {'_id': ObjectId('61d20d53d9221e342731fa5a'), 'siruta': 154932, 'lhdi_2018_pred': 31.7}
# {'_id': ObjectId('61d20d53d9221e342731fa5b'), 'siruta': 74509, 'lhdi_2018_pred': 37.5}
# {'_id': ObjectId('61d20d53d9221e342731fa5c'), 'siruta': 152724, 'lhdi_2018_pred': 37.7}
# {'_id': ObjectId('61d20d53d9221e342731fa5d'), 'siruta': 105605, 'lhdi_2018_pred': 39.6}
# {'_id': ObjectId('61d20d53d9221e342731fa5e'), 'siruta': 111444, 'lhdi_2018_pred': 42.6}
# {'_id': ObjectId('61d20d53d9221e342731fa5f'), 'siruta': 74411, 'lhdi_2018_pred': 40.7}
# {'_id': ObjectId('61d20d53d9221e342731fa60'), 'siruta': 102419, 'lhdi_2018_pred': 39.1}
# {'_id': ObjectId('61d20d53d9221e342731fa61'), 'siruta': 74732, 'lhdi_2018_pred': 37.6}
# {'_id': ObjectId('61d20d53d9221e342731fa62'), 'siruta': 100638, 'lhdi_2018_pred': 37.5}
# {'_id': ObjectId('61d20d53d9221e342731fa63'), 'siruta': 130357, 'lhdi_2018_pred': 37.4}
# {'_id': ObjectId('61d20d53d9221e342731fa64'), 'siruta': 126978, 'lhdi_2018_pred': 39.3}
# {'_id': ObjectId('61d20d53d9221e342731fa65'), 'siruta': 105776, 'lhdi_2018_pred': 52.5}
# {'_id': ObjectId('61d20d53d9221e342731fa66'), 'siruta': 114079, 'lhdi_2018_pred': 39.1}
# {'_id': ObjectId('61d20d53d9221e342731fa67'), 'siruta': 72926, 'lhdi_2018_pred': 44.8}
# {'_id': ObjectId('61d20d53d9221e342731fa68'), 'siruta': 111550, 'lhdi_2018_pred': 35.1}
# {'_id': ObjectId('61d20d53d9221e342731fa69'), 'siruta': 129763, 'lhdi_2018_pred': 29.8}
# {'_id': ObjectId('61d20d53d9221e342731fa6a'), 'siruta': 127386, 'lhdi_2018_pred': 25}
# {'_id': ObjectId('61d20d53d9221e342731fa6b'), 'siruta': 105106, 'lhdi_2018_pred': 41}
# {'_id': ObjectId('61d20d53d9221e342731fa6c'), 'siruta': 105384, 'lhdi_2018_pred': 35.9}
# {'_id': ObjectId('61d20d53d9221e342731fa6d'), 'siruta': 155092, 'lhdi_2018_pred': 32.3}
# {'_id': ObjectId('61d20d53d9221e342731fa6e'), 'siruta': 114060, 'lhdi_2018_pred': 39.2}
# {'_id': ObjectId('61d20d53d9221e342731fa6f'), 'siruta': 127493, 'lhdi_2018_pred': 33.9}
# {'_id': ObjectId('61d20d53d9221e342731fa70'), 'siruta': 129111, 'lhdi_2018_pred': 33.4}
# {'_id': ObjectId('61d20d53d9221e342731fa71'), 'siruta': 127714, 'lhdi_2018_pred': 30.8}
# {'_id': ObjectId('61d20d53d9221e342731fa72'), 'siruta': 74750, 'lhdi_2018_pred': 33.9}
# {'_id': ObjectId('61d20d53d9221e342731fa73'), 'siruta': 71885, 'lhdi_2018_pred': 56.4}
# {'_id': ObjectId('61d20d53d9221e342731fa74'), 'siruta': 179588, 'lhdi_2018_pred': 71.2}
# {'_id': ObjectId('61d20d53d9221e342731fa75'), 'siruta': 111783, 'lhdi_2018_pred': 29.9}
# {'_id': ObjectId('61d20d53d9221e342731fa76'), 'siruta': 153437, 'lhdi_2018_pred': 26.4}
# {'_id': ObjectId('61d20d53d9221e342731fa77'), 'siruta': 73068, 'lhdi_2018_pred': 71}
# {'_id': ObjectId('61d20d53d9221e342731fa78'), 'siruta': 74028, 'lhdi_2018_pred': 36.5}
# {'_id': ObjectId('61d20d53d9221e342731fa79'), 'siruta': 127983, 'lhdi_2018_pred': 38.8}
# {'_id': ObjectId('61d20d53d9221e342731fa7a'), 'siruta': 100781, 'lhdi_2018_pred': 50.1}
# {'_id': ObjectId('61d20d53d9221e342731fa7b'), 'siruta': 113849, 'lhdi_2018_pred': 41.2}
# {'_id': ObjectId('61d20d53d9221e342731fa7c'), 'siruta': 104083, 'lhdi_2018_pred': 27}
# {'_id': ObjectId('61d20d53d9221e342731fa7d'), 'siruta': 72150, 'lhdi_2018_pred': 40.9}
# {'_id': ObjectId('61d20d53d9221e342731fa7e'), 'siruta': 74859, 'lhdi_2018_pred': 91.3}
# {'_id': ObjectId('61d20d53d9221e342731fa7f'), 'siruta': 151905, 'lhdi_2018_pred': 58.5}
# {'_id': ObjectId('61d20d53d9221e342731fa80'), 'siruta': 130311, 'lhdi_2018_pred': 27.6}
# {'_id': ObjectId('61d20d53d9221e342731fa81'), 'siruta': 154754, 'lhdi_2018_pred': 21.3}
# {'_id': ObjectId('61d20d53d9221e342731fa82'), 'siruta': 130384, 'lhdi_2018_pred': 43.8}
# {'_id': ObjectId('61d20d53d9221e342731fa83'), 'siruta': 105829, 'lhdi_2018_pred': 34.7}
# {'_id': ObjectId('61d20d53d9221e342731fa84'), 'siruta': 126406, 'lhdi_2018_pred': 27.4}
# {'_id': ObjectId('61d20d53d9221e342731fa85'), 'siruta': 126380, 'lhdi_2018_pred': 43.5}
# {'_id': ObjectId('61d20d53d9221e342731fa86'), 'siruta': 73503, 'lhdi_2018_pred': 35.2}
# {'_id': ObjectId('61d20d53d9221e342731fa87'), 'siruta': 154978, 'lhdi_2018_pred': 27.9}
# {'_id': ObjectId('61d20d53d9221e342731fa88'), 'siruta': 74359, 'lhdi_2018_pred': 32.5}
# {'_id': ObjectId('61d20d53d9221e342731fa89'), 'siruta': 105936, 'lhdi_2018_pred': 73.2}
# {'_id': ObjectId('61d20d53d9221e342731fa8a'), 'siruta': 74705, 'lhdi_2018_pred': 38.6}
# {'_id': ObjectId('61d20d53d9221e342731fa8b'), 'siruta': 129987, 'lhdi_2018_pred': 30.9}
# {'_id': ObjectId('61d20d53d9221e342731fa8c'), 'siruta': 92569, 'lhdi_2018_pred': 60.6}
# {'_id': ObjectId('61d20d53d9221e342731fa8d'), 'siruta': 74616, 'lhdi_2018_pred': 41.9}
# {'_id': ObjectId('61d20d53d9221e342731fa8e'), 'siruta': 93325, 'lhdi_2018_pred': 49}
# {'_id': ObjectId('61d20d53d9221e342731fa8f'), 'siruta': 93441, 'lhdi_2018_pred': 44.6}
# {'_id': ObjectId('61d20d53d9221e342731fa90'), 'siruta': 128178, 'lhdi_2018_pred': 40.8}
# {'_id': ObjectId('61d20d53d9221e342731fa91'), 'siruta': 94312, 'lhdi_2018_pred': 41.7}
# {'_id': ObjectId('61d20d53d9221e342731fa92'), 'siruta': 73923, 'lhdi_2018_pred': 36.4}
# {'_id': ObjectId('61d20d53d9221e342731fa93'), 'siruta': 126022, 'lhdi_2018_pred': 29.9}
# {'_id': ObjectId('61d20d53d9221e342731fa94'), 'siruta': 101984, 'lhdi_2018_pred': 29.5}
# {'_id': ObjectId('61d20d53d9221e342731fa95'), 'siruta': 112771, 'lhdi_2018_pred': 28.9}
# {'_id': ObjectId('61d20d53d9221e342731fa96'), 'siruta': 130348, 'lhdi_2018_pred': 33.9}
# {'_id': ObjectId('61d20d53d9221e342731fa97'), 'siruta': 93085, 'lhdi_2018_pred': 46.5}
# {'_id': ObjectId('61d20d53d9221e342731fa98'), 'siruta': 92587, 'lhdi_2018_pred': 51.1}
# {'_id': ObjectId('61d20d53d9221e342731fa99'), 'siruta': 125846, 'lhdi_2018_pred': 44.6}
# {'_id': ObjectId('61d20d53d9221e342731fa9a'), 'siruta': 104323, 'lhdi_2018_pred': 45.8}
# {'_id': ObjectId('61d20d53d9221e342731fa9b'), 'siruta': 179962, 'lhdi_2018_pred': 31.7}
# {'_id': ObjectId('61d20d53d9221e342731fa9c'), 'siruta': 112030, 'lhdi_2018_pred': 31.3}
# {'_id': ObjectId('61d20d53d9221e342731fa9d'), 'siruta': 113395, 'lhdi_2018_pred': 30.2}
# {'_id': ObjectId('61d20d53d9221e342731fa9e'), 'siruta': 129246, 'lhdi_2018_pred': 35.9}
# {'_id': ObjectId('61d20d53d9221e342731fa9f'), 'siruta': 94606, 'lhdi_2018_pred': 39.3}
# {'_id': ObjectId('61d20d53d9221e342731faa0'), 'siruta': 151996, 'lhdi_2018_pred': 35.5}
# {'_id': ObjectId('61d20d53d9221e342731faa1'), 'siruta': 74931, 'lhdi_2018_pred': 24.9}
# {'_id': ObjectId('61d20d53d9221e342731faa2'), 'siruta': 69900, 'lhdi_2018_pred': 69.7}
# {'_id': ObjectId('61d20d53d9221e342731faa3'), 'siruta': 71260, 'lhdi_2018_pred': 43.4}
# {'_id': ObjectId('61d20d53d9221e342731faa4'), 'siruta': 71536, 'lhdi_2018_pred': 12.4}
# {'_id': ObjectId('61d20d53d9221e342731faa5'), 'siruta': 73629, 'lhdi_2018_pred': 70.3}
# {'_id': ObjectId('61d20d53d9221e342731faa6'), 'siruta': 93664, 'lhdi_2018_pred': 48}
# {'_id': ObjectId('61d20d53d9221e342731faa7'), 'siruta': 94125, 'lhdi_2018_pred': 42.6}
# {'_id': ObjectId('61d20d53d9221e342731faa8'), 'siruta': 94651, 'lhdi_2018_pred': 46.1}
# {'_id': ObjectId('61d20d53d9221e342731faa9'), 'siruta': 102838, 'lhdi_2018_pred': 28.7}
# {'_id': ObjectId('61d20d53d9221e342731faaa'), 'siruta': 129585, 'lhdi_2018_pred': 26.5}
# {'_id': ObjectId('61d20d53d9221e342731faab'), 'siruta': 112879, 'lhdi_2018_pred': 38.9}
# {'_id': ObjectId('61d20d53d9221e342731faac'), 'siruta': 94580, 'lhdi_2018_pred': 32.2}
# {'_id': ObjectId('61d20d53d9221e342731faad'), 'siruta': 127563, 'lhdi_2018_pred': 39.6}
# {'_id': ObjectId('61d20d53d9221e342731faae'), 'siruta': 154228, 'lhdi_2018_pred': 33.6}
# {'_id': ObjectId('61d20d53d9221e342731faaf'), 'siruta': 154282, 'lhdi_2018_pred': 36}
# {'_id': ObjectId('61d20d53d9221e342731fab0'), 'siruta': 74135, 'lhdi_2018_pred': 12.8624278126}
# {'_id': ObjectId('61d20d53d9221e342731fab1'), 'siruta': 70986, 'lhdi_2018_pred': 16.9}
# {'_id': ObjectId('61d20d53d9221e342731fab2'), 'siruta': 101378, 'lhdi_2018_pred': 36.5}
# {'_id': ObjectId('61d20d53d9221e342731fab3'), 'siruta': 154068, 'lhdi_2018_pred': 26.3}
# {'_id': ObjectId('61d20d53d9221e342731fab4'), 'siruta': 128105, 'lhdi_2018_pred': 48.3}
# {'_id': ObjectId('61d20d53d9221e342731fab5'), 'siruta': 104225, 'lhdi_2018_pred': 37.5}
# {'_id': ObjectId('61d20d53d9221e342731fab6'), 'siruta': 93771, 'lhdi_2018_pred': 40.8}
# {'_id': ObjectId('61d20d53d9221e342731fab7'), 'siruta': 93815, 'lhdi_2018_pred': 41.5}
# {'_id': ObjectId('61d20d53d9221e342731fab8'), 'siruta': 105222, 'lhdi_2018_pred': 31.9}
# {'_id': ObjectId('61d20d53d9221e342731fab9'), 'siruta': 125677, 'lhdi_2018_pred': 39.6}
# {'_id': ObjectId('61d20d53d9221e342731faba'), 'siruta': 113929, 'lhdi_2018_pred': 27.6}
# {'_id': ObjectId('61d20d53d9221e342731fabb'), 'siruta': 72409, 'lhdi_2018_pred': 72.7}
# {'_id': ObjectId('61d20d53d9221e342731fabc'), 'siruta': 105712, 'lhdi_2018_pred': 40.6}
# {'_id': ObjectId('61d20d53d9221e342731fabd'), 'siruta': 104635, 'lhdi_2018_pred': 41}
# {'_id': ObjectId('61d20d53d9221e342731fabe'), 'siruta': 127689, 'lhdi_2018_pred': 27.6}
# {'_id': ObjectId('61d20d53d9221e342731fabf'), 'siruta': 70094, 'lhdi_2018_pred': 67.4}
# {'_id': ObjectId('61d20d53d9221e342731fac0'), 'siruta': 17398, 'lhdi_2018_pred': 37.5}
# {'_id': ObjectId('61d20d53d9221e342731fac1'), 'siruta': 125873, 'lhdi_2018_pred': 47.4}
# {'_id': ObjectId('61d20d53d9221e342731fac2'), 'siruta': 104485, 'lhdi_2018_pred': 46.7}
# {'_id': ObjectId('61d20d53d9221e342731fac3'), 'siruta': 73772, 'lhdi_2018_pred': 38}
# {'_id': ObjectId('61d20d53d9221e342731fac4'), 'siruta': 103407, 'lhdi_2018_pred': 53.8}
# {'_id': ObjectId('61d20d53d9221e342731fac5'), 'siruta': 125374, 'lhdi_2018_pred': 71.4}
# {'_id': ObjectId('61d20d53d9221e342731fac6'), 'siruta': 93281, 'lhdi_2018_pred': 46.2}
# {'_id': ObjectId('61d20d53d9221e342731fac7'), 'siruta': 111417, 'lhdi_2018_pred': 30}
# {'_id': ObjectId('61d20d53d9221e342731fac8'), 'siruta': 74242, 'lhdi_2018_pred': 23.4}
# {'_id': ObjectId('61d20d53d9221e342731fac9'), 'siruta': 154665, 'lhdi_2018_pred': 23.8}
# {'_id': ObjectId('61d20d53d9221e342731faca'), 'siruta': 127812, 'lhdi_2018_pred': 50.4}
# {'_id': ObjectId('61d20d53d9221e342731facb'), 'siruta': 70968, 'lhdi_2018_pred': 21.6060387669}
# {'_id': ObjectId('61d20d53d9221e342731facc'), 'siruta': 72604, 'lhdi_2018_pred': 17.2583143321}
# {'_id': ObjectId('61d20d53d9221e342731facd'), 'siruta': 93931, 'lhdi_2018_pred': 38.8}
# {'_id': ObjectId('61d20d53d9221e342731face'), 'siruta': 94731, 'lhdi_2018_pred': 39.7}
# {'_id': ObjectId('61d20d53d9221e342731facf'), 'siruta': 94768, 'lhdi_2018_pred': 37.1}
# {'_id': ObjectId('61d20d53d9221e342731fad0'), 'siruta': 110535, 'lhdi_2018_pred': 31.5}
# {'_id': ObjectId('61d20d53d9221e342731fad1'), 'siruta': 130302, 'lhdi_2018_pred': 36.7}
# {'_id': ObjectId('61d20d53d9221e342731fad2'), 'siruta': 128052, 'lhdi_2018_pred': 38.3}
# {'_id': ObjectId('61d20d53d9221e342731fad3'), 'siruta': 111863, 'lhdi_2018_pred': 55.9}
# {'_id': ObjectId('61d20d53d9221e342731fad4'), 'siruta': 127064, 'lhdi_2018_pred': 44.9}
# {'_id': ObjectId('61d20d53d9221e342731fad5'), 'siruta': 127322, 'lhdi_2018_pred': 46.5}
# {'_id': ObjectId('61d20d53d9221e342731fad6'), 'siruta': 112548, 'lhdi_2018_pred': 34}
# {'_id': ObjectId('61d20d53d9221e342731fad7'), 'siruta': 20048, 'lhdi_2018_pred': 37.4}
# {'_id': ObjectId('61d20d53d9221e342731fad8'), 'siruta': 71910, 'lhdi_2018_pred': 33}
# {'_id': ObjectId('61d20d53d9221e342731fad9'), 'siruta': 70174, 'lhdi_2018_pred': 59.3}
# {'_id': ObjectId('61d20d53d9221e342731fada'), 'siruta': 104831, 'lhdi_2018_pred': 54}
# {'_id': ObjectId('61d20d53d9221e342731fadb'), 'siruta': 102348, 'lhdi_2018_pred': 37}
# {'_id': ObjectId('61d20d53d9221e342731fadc'), 'siruta': 101190, 'lhdi_2018_pred': 61.8}
# {'_id': ObjectId('61d20d53d9221e342731fadd'), 'siruta': 15064, 'lhdi_2018_pred': 35.2}
# {'_id': ObjectId('61d20d53d9221e342731fade'), 'siruta': 130295, 'lhdi_2018_pred': 38.4}
# {'_id': ObjectId('61d20d53d9221e342731fadf'), 'siruta': 101163, 'lhdi_2018_pred': 73}
# {'_id': ObjectId('61d20d53d9221e342731fae0'), 'siruta': 153696, 'lhdi_2018_pred': 37.2}
# {'_id': ObjectId('61d20d53d9221e342731fae1'), 'siruta': 71723, 'lhdi_2018_pred': 16.3}
# {'_id': ObjectId('61d20d53d9221e342731fae2'), 'siruta': 74875, 'lhdi_2018_pred': 34.6}
# {'_id': ObjectId('61d20d53d9221e342731fae3'), 'siruta': 104341, 'lhdi_2018_pred': 36.9}
# {'_id': ObjectId('61d20d53d9221e342731fae4'), 'siruta': 70566, 'lhdi_2018_pred': 52.1}
# {'_id': ObjectId('61d20d53d9221e342731fae5'), 'siruta': 72819, 'lhdi_2018_pred': 24.7}
# {'_id': ObjectId('61d20d53d9221e342731fae6'), 'siruta': 130286, 'lhdi_2018_pred': 43}
# {'_id': ObjectId('61d20d53d9221e342731fae7'), 'siruta': 14450, 'lhdi_2018_pred': 43.2}
# {'_id': ObjectId('61d20d53d9221e342731fae8'), 'siruta': 74073, 'lhdi_2018_pred': 35.3}
# {'_id': ObjectId('61d20d53d9221e342731fae9'), 'siruta': 94492, 'lhdi_2018_pred': 51}
# {'_id': ObjectId('61d20d53d9221e342731faea'), 'siruta': 110232, 'lhdi_2018_pred': 48}
# {'_id': ObjectId('61d20d53d9221e342731faeb'), 'siruta': 112806, 'lhdi_2018_pred': 20.3}
# {'_id': ObjectId('61d20d53d9221e342731faec'), 'siruta': 92701, 'lhdi_2018_pred': 59.2}
# {'_id': ObjectId('61d20d53d9221e342731faed'), 'siruta': 128374, 'lhdi_2018_pred': 54}
# {'_id': ObjectId('61d20d53d9221e342731faee'), 'siruta': 19114, 'lhdi_2018_pred': 42.9}
# {'_id': ObjectId('61d20d53d9221e342731faef'), 'siruta': 128221, 'lhdi_2018_pred': 55.4}
# {'_id': ObjectId('61d20d53d9221e342731faf0'), 'siruta': 74171, 'lhdi_2018_pred': 23.2}
# {'_id': ObjectId('61d20d53d9221e342731faf1'), 'siruta': 126326, 'lhdi_2018_pred': 33.4}
# {'_id': ObjectId('61d20d53d9221e342731faf2'), 'siruta': 126433, 'lhdi_2018_pred': 45.9}
# {'_id': ObjectId('61d20d53d9221e342731faf3'), 'siruta': 127625, 'lhdi_2018_pred': 31.4}
# {'_id': ObjectId('61d20d53d9221e342731faf4'), 'siruta': 93539, 'lhdi_2018_pred': 38.6}
# {'_id': ObjectId('61d20d53d9221e342731faf5'), 'siruta': 105455, 'lhdi_2018_pred': 34}
# {'_id': ObjectId('61d20d53d9221e342731faf6'), 'siruta': 68887, 'lhdi_2018_pred': 23}
# {'_id': ObjectId('61d20d53d9221e342731faf7'), 'siruta': 72677, 'lhdi_2018_pred': 49.5}
# {'_id': ObjectId('61d20d53d9221e342731faf8'), 'siruta': 103032, 'lhdi_2018_pred': 58.1}
# {'_id': ObjectId('61d20d53d9221e342731faf9'), 'siruta': 105972, 'lhdi_2018_pred': 39.7}
# {'_id': ObjectId('61d20d53d9221e342731fafa'), 'siruta': 93851, 'lhdi_2018_pred': 44.7}
# {'_id': ObjectId('61d20d53d9221e342731fafb'), 'siruta': 179775, 'lhdi_2018_pred': 68.1}
# {'_id': ObjectId('61d20d53d9221e342731fafc'), 'siruta': 113153, 'lhdi_2018_pred': 26.4631843651}
# {'_id': ObjectId('61d20d53d9221e342731fafd'), 'siruta': 102794, 'lhdi_2018_pred': 59}
# {'_id': ObjectId('61d20d53d9221e342731fafe'), 'siruta': 105623, 'lhdi_2018_pred': 51.1}
# {'_id': ObjectId('61d20d53d9221e342731faff'), 'siruta': 16613, 'lhdi_2018_pred': 42.1}
# {'_id': ObjectId('61d20d53d9221e342731fb00'), 'siruta': 103087, 'lhdi_2018_pred': 38.3}
# {'_id': ObjectId('61d20d53d9221e342731fb01'), 'siruta': 70744, 'lhdi_2018_pred': 22.6}
# {'_id': ObjectId('61d20d53d9221e342731fb02'), 'siruta': 129139, 'lhdi_2018_pred': 36.4}
# {'_id': ObjectId('61d20d53d9221e342731fb03'), 'siruta': 126166, 'lhdi_2018_pred': 44.2}
# {'_id': ObjectId('61d20d53d9221e342731fb04'), 'siruta': 111480, 'lhdi_2018_pred': 35.3}
# {'_id': ObjectId('61d20d53d9221e342731fb05'), 'siruta': 19560, 'lhdi_2018_pred': 31.1}
# {'_id': ObjectId('61d20d53d9221e342731fb06'), 'siruta': 71055, 'lhdi_2018_pred': 53.1}
# {'_id': ObjectId('61d20d53d9221e342731fb07'), 'siruta': 18741, 'lhdi_2018_pred': 45.6}
# {'_id': ObjectId('61d20d53d9221e342731fb08'), 'siruta': 170612, 'lhdi_2018_pred': 40.2}
# {'_id': ObjectId('61d20d53d9221e342731fb09'), 'siruta': 92989, 'lhdi_2018_pred': 40.9}
# {'_id': ObjectId('61d20d53d9221e342731fb0a'), 'siruta': 110946, 'lhdi_2018_pred': 39.3}
# {'_id': ObjectId('61d20d53d9221e342731fb0b'), 'siruta': 179793, 'lhdi_2018_pred': 34.6}
# {'_id': ObjectId('61d20d53d9221e342731fb0c'), 'siruta': 130366, 'lhdi_2018_pred': 41.4}
# {'_id': ObjectId('61d20d53d9221e342731fb0d'), 'siruta': 101083, 'lhdi_2018_pred': 64.9}
# {'_id': ObjectId('61d20d53d9221e342731fb0e'), 'siruta': 94223, 'lhdi_2018_pred': 48.4}
# {'_id': ObjectId('61d20d53d9221e342731fb0f'), 'siruta': 92783, 'lhdi_2018_pred': 32.3}
# {'_id': ObjectId('61d20d53d9221e342731fb10'), 'siruta': 68431, 'lhdi_2018_pred': 45.3}
# {'_id': ObjectId('61d20d53d9221e342731fb11'), 'siruta': 129380, 'lhdi_2018_pred': 39.8}
# {'_id': ObjectId('61d20d53d9221e342731fb12'), 'siruta': 17575, 'lhdi_2018_pred': 48.6}
# {'_id': ObjectId('61d20d53d9221e342731fb13'), 'siruta': 127171, 'lhdi_2018_pred': 41}
# {'_id': ObjectId('61d20d53d9221e342731fb14'), 'siruta': 103764, 'lhdi_2018_pred': 13.6}
# {'_id': ObjectId('61d20d53d9221e342731fb15'), 'siruta': 73102, 'lhdi_2018_pred': 57}
# {'_id': ObjectId('61d20d53d9221e342731fb16'), 'siruta': 169583, 'lhdi_2018_pred': 56.4}
# {'_id': ObjectId('61d20d53d9221e342731fb17'), 'siruta': 111916, 'lhdi_2018_pred': 29.6}
# {'_id': ObjectId('61d20d53d9221e342731fb18'), 'siruta': 127901, 'lhdi_2018_pred': 34.1}
# {'_id': ObjectId('61d20d53d9221e342731fb19'), 'siruta': 102641, 'lhdi_2018_pred': 43.5684819221}
# {'_id': ObjectId('61d20d53d9221e342731fb1a'), 'siruta': 112600, 'lhdi_2018_pred': 29}
# {'_id': ObjectId('61d20d53d9221e342731fb1b'), 'siruta': 100576, 'lhdi_2018_pred': 69.9}
# {'_id': ObjectId('61d20d53d9221e342731fb1c'), 'siruta': 105142, 'lhdi_2018_pred': 51.5}
# {'_id': ObjectId('61d20d53d9221e342731fb1d'), 'siruta': 68468, 'lhdi_2018_pred': 50.9}
# {'_id': ObjectId('61d20d53d9221e342731fb1e'), 'siruta': 70414, 'lhdi_2018_pred': 52.9}
# {'_id': ObjectId('61d20d53d9221e342731fb1f'), 'siruta': 18938, 'lhdi_2018_pred': 46.1}
# {'_id': ObjectId('61d20d53d9221e342731fb20'), 'siruta': 112076, 'lhdi_2018_pred': 35.1}
# {'_id': ObjectId('61d20d53d9221e342731fb21'), 'siruta': 174218, 'lhdi_2018_pred': 59.7}
# {'_id': ObjectId('61d20d53d9221e342731fb22'), 'siruta': 69330, 'lhdi_2018_pred': 40.3}
# {'_id': ObjectId('61d20d53d9221e342731fb23'), 'siruta': 127858, 'lhdi_2018_pred': 37.2}
# {'_id': ObjectId('61d20d53d9221e342731fb24'), 'siruta': 68342, 'lhdi_2018_pred': 33.3}
# {'_id': ObjectId('61d20d53d9221e342731fb25'), 'siruta': 94535, 'lhdi_2018_pred': 47.5}
# {'_id': ObjectId('61d20d53d9221e342731fb26'), 'siruta': 179828, 'lhdi_2018_pred': 51.1}
# {'_id': ObjectId('61d20d53d9221e342731fb27'), 'siruta': 73371, 'lhdi_2018_pred': 41.5}
# {'_id': ObjectId('61d20d53d9221e342731fb28'), 'siruta': 174502, 'lhdi_2018_pred': 41.5}
# {'_id': ObjectId('61d20d53d9221e342731fb29'), 'siruta': 173748, 'lhdi_2018_pred': 52.8}
# {'_id': ObjectId('61d20d53d9221e342731fb2a'), 'siruta': 92872, 'lhdi_2018_pred': 43}
# {'_id': ObjectId('61d20d53d9221e342731fb2b'), 'siruta': 173793, 'lhdi_2018_pred': 42.3}
# {'_id': ObjectId('61d20d53d9221e342731fb2c'), 'siruta': 67906, 'lhdi_2018_pred': 54.4}
# {'_id': ObjectId('61d20d53d9221e342731fb2d'), 'siruta': 170952, 'lhdi_2018_pred': 38}
# {'_id': ObjectId('61d20d53d9221e342731fb2e'), 'siruta': 101840, 'lhdi_2018_pred': 45.1}
# {'_id': ObjectId('61d20d53d9221e342731fb2f'), 'siruta': 94376, 'lhdi_2018_pred': 36.2}
# {'_id': ObjectId('61d20d53d9221e342731fb30'), 'siruta': 100923, 'lhdi_2018_pred': 26.8}
# {'_id': ObjectId('61d20d53d9221e342731fb31'), 'siruta': 180000, 'lhdi_2018_pred': 35.7}
# {'_id': ObjectId('61d20d53d9221e342731fb32'), 'siruta': 67121, 'lhdi_2018_pred': 41}
# {'_id': ObjectId('61d20d53d9221e342731fb33'), 'siruta': 94161, 'lhdi_2018_pred': 41.3}
# {'_id': ObjectId('61d20d53d9221e342731fb34'), 'siruta': 104270, 'lhdi_2018_pred': 45.3}
# {'_id': ObjectId('61d20d53d9221e342731fb35'), 'siruta': 80560, 'lhdi_2018_pred': 42.7}
# {'_id': ObjectId('61d20d53d9221e342731fb36'), 'siruta': 126228, 'lhdi_2018_pred': 40.3}
# {'_id': ObjectId('61d20d53d9221e342731fb37'), 'siruta': 19212, 'lhdi_2018_pred': 36.2}
# {'_id': ObjectId('61d20d53d9221e342731fb38'), 'siruta': 82680, 'lhdi_2018_pred': 52.4}
# {'_id': ObjectId('61d20d53d9221e342731fb39'), 'siruta': 113974, 'lhdi_2018_pred': 21.1}
# {'_id': ObjectId('61d20d53d9221e342731fb3a'), 'siruta': 129317, 'lhdi_2018_pred': 37.0972308899}
# {'_id': ObjectId('61d20d53d9221e342731fb3b'), 'siruta': 68253, 'lhdi_2018_pred': 26.7}
# {'_id': ObjectId('61d20d53d9221e342731fb3c'), 'siruta': 167981, 'lhdi_2018_pred': 63.9}
# {'_id': ObjectId('61d20d53d9221e342731fb3d'), 'siruta': 101056, 'lhdi_2018_pred': 27.4}
# {'_id': ObjectId('61d20d53d9221e342731fb3e'), 'siruta': 129816, 'lhdi_2018_pred': 39.1}
# {'_id': ObjectId('61d20d53d9221e342731fb3f'), 'siruta': 68128, 'lhdi_2018_pred': 36.3}
# {'_id': ObjectId('61d20d53d9221e342731fb40'), 'siruta': 93628, 'lhdi_2018_pred': 40.5}
# {'_id': ObjectId('61d20d53d9221e342731fb41'), 'siruta': 173597, 'lhdi_2018_pred': 58.6}
# {'_id': ObjectId('61d20d53d9221e342731fb42'), 'siruta': 110116, 'lhdi_2018_pred': 44.3}
# {'_id': ObjectId('61d20d53d9221e342731fb43'), 'siruta': 65752, 'lhdi_2018_pred': 38.8}
# {'_id': ObjectId('61d20d53d9221e342731fb44'), 'siruta': 168452, 'lhdi_2018_pred': 52.2}
# {'_id': ObjectId('61d20d53d9221e342731fb45'), 'siruta': 66768, 'lhdi_2018_pred': 42.8}
# {'_id': ObjectId('61d20d53d9221e342731fb46'), 'siruta': 92836, 'lhdi_2018_pred': 62.1}
# {'_id': ObjectId('61d20d53d9221e342731fb47'), 'siruta': 171209, 'lhdi_2018_pred': 42.9}
# {'_id': ObjectId('61d20d53d9221e342731fb48'), 'siruta': 79237, 'lhdi_2018_pred': 46.2}
# {'_id': ObjectId('61d20d53d9221e342731fb49'), 'siruta': 93021, 'lhdi_2018_pred': 47.2}
# {'_id': ObjectId('61d20d53d9221e342731fb4a'), 'siruta': 68627, 'lhdi_2018_pred': 57}
# {'_id': ObjectId('61d20d53d9221e342731fb4b'), 'siruta': 101564, 'lhdi_2018_pred': 47.3}
# {'_id': ObjectId('61d20d53d9221e342731fb4c'), 'siruta': 93067, 'lhdi_2018_pred': 51.4}
# {'_id': ObjectId('61d20d53d9221e342731fb4d'), 'siruta': 93600, 'lhdi_2018_pred': 46.3}
# {'_id': ObjectId('61d20d53d9221e342731fb4e'), 'siruta': 82314, 'lhdi_2018_pred': 48.4}
# {'_id': ObjectId('61d20d53d9221e342731fb4f'), 'siruta': 102749, 'lhdi_2018_pred': 49.7}
# {'_id': ObjectId('61d20d53d9221e342731fb50'), 'siruta': 179819, 'lhdi_2018_pred': 50.3}
# {'_id': ObjectId('61d20d53d9221e342731fb51'), 'siruta': 94795, 'lhdi_2018_pred': 41.1}
# {'_id': ObjectId('61d20d53d9221e342731fb52'), 'siruta': 68529, 'lhdi_2018_pred': 45.5}
# {'_id': ObjectId('61d20d53d9221e342731fb53'), 'siruta': 112129, 'lhdi_2018_pred': 18.4}
# {'_id': ObjectId('61d20d53d9221e342731fb54'), 'siruta': 103862, 'lhdi_2018_pred': 40.4}
# {'_id': ObjectId('61d20d53d9221e342731fb55'), 'siruta': 94456, 'lhdi_2018_pred': 47.2}
# {'_id': ObjectId('61d20d53d9221e342731fb56'), 'siruta': 128301, 'lhdi_2018_pred': 36.2}
# {'_id': ObjectId('61d20d53d9221e342731fb57'), 'siruta': 111275, 'lhdi_2018_pred': 33.7}
# {'_id': ObjectId('61d20d53d9221e342731fb58'), 'siruta': 169306, 'lhdi_2018_pred': 50.9}
# {'_id': ObjectId('61d20d53d9221e342731fb59'), 'siruta': 66697, 'lhdi_2018_pred': 27.7}
# {'_id': ObjectId('61d20d53d9221e342731fb5a'), 'siruta': 16944, 'lhdi_2018_pred': 43.2}
# {'_id': ObjectId('61d20d53d9221e342731fb5b'), 'siruta': 94107, 'lhdi_2018_pred': 45.8}
# {'_id': ObjectId('61d20d53d9221e342731fb5c'), 'siruta': 93995, 'lhdi_2018_pred': 44.9}
# {'_id': ObjectId('61d20d53d9221e342731fb5d'), 'siruta': 65681, 'lhdi_2018_pred': 65.7}
# {'_id': ObjectId('61d20d53d9221e342731fb5e'), 'siruta': 174511, 'lhdi_2018_pred': 33.7}
# {'_id': ObjectId('61d20d53d9221e342731fb5f'), 'siruta': 19007, 'lhdi_2018_pred': 51}
# {'_id': ObjectId('61d20d53d9221e342731fb60'), 'siruta': 125757, 'lhdi_2018_pred': 31.9}
# {'_id': ObjectId('61d20d53d9221e342731fb61'), 'siruta': 170097, 'lhdi_2018_pred': 29.4}
# {'_id': ObjectId('61d20d53d9221e342731fb62'), 'siruta': 53489, 'lhdi_2018_pred': 48}
# {'_id': ObjectId('61d20d53d9221e342731fb63'), 'siruta': 68048, 'lhdi_2018_pred': 32.6}
# {'_id': ObjectId('61d20d53d9221e342731fb64'), 'siruta': 126503, 'lhdi_2018_pred': 39.9}
# {'_id': ObjectId('61d20d53d9221e342731fb65'), 'siruta': 79157, 'lhdi_2018_pred': 40.6}
# {'_id': ObjectId('61d20d53d9221e342731fb66'), 'siruta': 100852, 'lhdi_2018_pred': 43.6}
# {'_id': ObjectId('61d20d53d9221e342731fb67'), 'siruta': 13668, 'lhdi_2018_pred': 61}
# {'_id': ObjectId('61d20d53d9221e342731fb68'), 'siruta': 94269, 'lhdi_2018_pred': 35.6}
# {'_id': ObjectId('61d20d53d9221e342731fb69'), 'siruta': 111097, 'lhdi_2018_pred': 24.5}
# {'_id': ObjectId('61d20d53d9221e342731fb6a'), 'siruta': 66955, 'lhdi_2018_pred': 32.5}
# {'_id': ObjectId('61d20d53d9221e342731fb6b'), 'siruta': 172457, 'lhdi_2018_pred': 55.1}
# {'_id': ObjectId('61d20d53d9221e342731fb6c'), 'siruta': 66401, 'lhdi_2018_pred': 45.3}
# {'_id': ObjectId('61d20d53d9221e342731fb6d'), 'siruta': 128962, 'lhdi_2018_pred': 31.7}
# {'_id': ObjectId('61d20d53d9221e342731fb6e'), 'siruta': 179800, 'lhdi_2018_pred': 46.8}
# {'_id': ObjectId('61d20d53d9221e342731fb6f'), 'siruta': 100736, 'lhdi_2018_pred': 57.5}
# {'_id': ObjectId('61d20d53d9221e342731fb70'), 'siruta': 130231, 'lhdi_2018_pred': 32.7}
# {'_id': ObjectId('61d20d53d9221e342731fb71'), 'siruta': 170444, 'lhdi_2018_pred': 45.8}
# {'_id': ObjectId('61d20d53d9221e342731fb72'), 'siruta': 82779, 'lhdi_2018_pred': 43.3}
# {'_id': ObjectId('61d20d53d9221e342731fb73'), 'siruta': 180064, 'lhdi_2018_pred': -3.54784972042e-13}
# {'_id': ObjectId('61d20d53d9221e342731fb74'), 'siruta': 67648, 'lhdi_2018_pred': 47.5}
# {'_id': ObjectId('61d20d53d9221e342731fb75'), 'siruta': 18581, 'lhdi_2018_pred': 46}
# {'_id': ObjectId('61d20d53d9221e342731fb76'), 'siruta': 68789, 'lhdi_2018_pred': 39.9}
# {'_id': ObjectId('61d20d53d9221e342731fb77'), 'siruta': 82617, 'lhdi_2018_pred': 65.5}
# {'_id': ObjectId('61d20d53d9221e342731fb78'), 'siruta': 171101, 'lhdi_2018_pred': 39.1}
# {'_id': ObjectId('61d20d53d9221e342731fb79'), 'siruta': 79077, 'lhdi_2018_pred': 43.2}
# {'_id': ObjectId('61d20d53d9221e342731fb7a'), 'siruta': 100683, 'lhdi_2018_pred': 65.5}
# {'_id': ObjectId('61d20d53d9221e342731fb7b'), 'siruta': 79497, 'lhdi_2018_pred': 43.4}
# {'_id': ObjectId('61d20d53d9221e342731fb7c'), 'siruta': 92907, 'lhdi_2018_pred': 43.1}
# {'_id': ObjectId('61d20d53d9221e342731fb7d'), 'siruta': 101243, 'lhdi_2018_pred': 31.5}
# {'_id': ObjectId('61d20d53d9221e342731fb7e'), 'siruta': 112664, 'lhdi_2018_pred': 40.4}
# {'_id': ObjectId('61d20d53d9221e342731fb7f'), 'siruta': 65707, 'lhdi_2018_pred': 43.9}
# {'_id': ObjectId('61d20d53d9221e342731fb80'), 'siruta': 126772, 'lhdi_2018_pred': 34.5}
# {'_id': ObjectId('61d20d53d9221e342731fb81'), 'siruta': 17824, 'lhdi_2018_pred': 54.7}
# {'_id': ObjectId('61d20d53d9221e342731fb82'), 'siruta': 94045, 'lhdi_2018_pred': 35.5}
# {'_id': ObjectId('61d20d53d9221e342731fb83'), 'siruta': 133508, 'lhdi_2018_pred': 65.9}
# {'_id': ObjectId('61d20d53d9221e342731fb84'), 'siruta': 110063, 'lhdi_2018_pred': 50.1}
# {'_id': ObjectId('61d20d53d9221e342731fb85'), 'siruta': 132226, 'lhdi_2018_pred': 50.2}
# {'_id': ObjectId('61d20d53d9221e342731fb86'), 'siruta': 110875, 'lhdi_2018_pred': 41}
# {'_id': ObjectId('61d20d53d9221e342731fb87'), 'siruta': 92765, 'lhdi_2018_pred': 48.5}
# {'_id': ObjectId('61d20d53d9221e342731fb88'), 'siruta': 136250, 'lhdi_2018_pred': 52.7}
# {'_id': ObjectId('61d20d53d9221e342731fb89'), 'siruta': 53853, 'lhdi_2018_pred': 43.3}
# {'_id': ObjectId('61d20d53d9221e342731fb8a'), 'siruta': 94688, 'lhdi_2018_pred': 44.1}
# {'_id': ObjectId('61d20d53d9221e342731fb8b'), 'siruta': 127411, 'lhdi_2018_pred': 20.7}
# {'_id': ObjectId('61d20d53d9221e342731fb8c'), 'siruta': 100754, 'lhdi_2018_pred': 38.1}
# {'_id': ObjectId('61d20d53d9221e342731fb8d'), 'siruta': 93209, 'lhdi_2018_pred': 39.8}
# {'_id': ObjectId('61d20d53d9221e342731fb8e'), 'siruta': 93717, 'lhdi_2018_pred': 53.7}
# {'_id': ObjectId('61d20d53d9221e342731fb8f'), 'siruta': 94429, 'lhdi_2018_pred': 44.7}
# {'_id': ObjectId('61d20d53d9221e342731fb90'), 'siruta': 105794, 'lhdi_2018_pred': 40.4}
# {'_id': ObjectId('61d20d53d9221e342731fb91'), 'siruta': 81656, 'lhdi_2018_pred': 44.8}
# {'_id': ObjectId('61d20d53d9221e342731fb92'), 'siruta': 179935, 'lhdi_2018_pred': 47.6}
# {'_id': ObjectId('61d20d53d9221e342731fb93'), 'siruta': 133429, 'lhdi_2018_pred': 38.9}
# {'_id': ObjectId('61d20d53d9221e342731fb94'), 'siruta': 174290, 'lhdi_2018_pred': 36}
# {'_id': ObjectId('61d20d53d9221e342731fb95'), 'siruta': 69170, 'lhdi_2018_pred': 52}
# {'_id': ObjectId('61d20d53d9221e342731fb96'), 'siruta': 171879, 'lhdi_2018_pred': 69.2}
# {'_id': ObjectId('61d20d53d9221e342731fb97'), 'siruta': 67167, 'lhdi_2018_pred': 37}
# {'_id': ObjectId('61d20d53d9221e342731fb98'), 'siruta': 100709, 'lhdi_2018_pred': 60.2664845551}
# {'_id': ObjectId('61d20d53d9221e342731fb99'), 'siruta': 67014, 'lhdi_2018_pred': 48.5}
# {'_id': ObjectId('61d20d53d9221e342731fb9a'), 'siruta': 103283, 'lhdi_2018_pred': 59}
# {'_id': ObjectId('61d20d53d9221e342731fb9b'), 'siruta': 13276, 'lhdi_2018_pred': 80.2}
# {'_id': ObjectId('61d20d53d9221e342731fb9c'), 'siruta': 135431, 'lhdi_2018_pred': 49.9}
# {'_id': ObjectId('61d20d53d9221e342731fb9d'), 'siruta': 68280, 'lhdi_2018_pred': 53.1}
# {'_id': ObjectId('61d20d53d9221e342731fb9e'), 'siruta': 16757, 'lhdi_2018_pred': 59.4}
# {'_id': ObjectId('61d20d53d9221e342731fb9f'), 'siruta': 180046, 'lhdi_2018_pred': 36.5}
# {'_id': ObjectId('61d20d53d9221e342731fba0'), 'siruta': 179971, 'lhdi_2018_pred': 36.9}
# {'_id': ObjectId('61d20d53d9221e342731fba1'), 'siruta': 82733, 'lhdi_2018_pred': 51.3}
# {'_id': ObjectId('61d20d53d9221e342731fba2'), 'siruta': 100870, 'lhdi_2018_pred': 35.3}
# {'_id': ObjectId('61d20d53d9221e342731fba3'), 'siruta': 67470, 'lhdi_2018_pred': 47.1}
# {'_id': ObjectId('61d20d53d9221e342731fba4'), 'siruta': 113625, 'lhdi_2018_pred': 30.1}
# {'_id': ObjectId('61d20d53d9221e342731fba5'), 'siruta': 80506, 'lhdi_2018_pred': 44.2}
# {'_id': ObjectId('61d20d53d9221e342731fba6'), 'siruta': 173855, 'lhdi_2018_pred': 32.1}
# {'_id': ObjectId('61d20d53d9221e342731fba7'), 'siruta': 173132, 'lhdi_2018_pred': 41.8}
# {'_id': ObjectId('61d20d53d9221e342731fba8'), 'siruta': 135850, 'lhdi_2018_pred': 45.6}
# {'_id': ObjectId('61d20d53d9221e342731fba9'), 'siruta': 169547, 'lhdi_2018_pred': 39.4}
# {'_id': ObjectId('61d20d53d9221e342731fbaa'), 'siruta': 81264, 'lhdi_2018_pred': 44.3}
# {'_id': ObjectId('61d20d53d9221e342731fbab'), 'siruta': 93646, 'lhdi_2018_pred': 45.7}
# {'_id': ObjectId('61d20d53d9221e342731fbac'), 'siruta': 128882, 'lhdi_2018_pred': 26.8}
# {'_id': ObjectId('61d20d53d9221e342731fbad'), 'siruta': 18028, 'lhdi_2018_pred': 54.6}
# {'_id': ObjectId('61d20d53d9221e342731fbae'), 'siruta': 67292, 'lhdi_2018_pred': 40.2}
# {'_id': ObjectId('61d20d53d9221e342731fbaf'), 'siruta': 170168, 'lhdi_2018_pred': 32.5}
# {'_id': ObjectId('61d20d53d9221e342731fbb0'), 'siruta': 78604, 'lhdi_2018_pred': 44.8}
# {'_id': ObjectId('61d20d53d9221e342731fbb1'), 'siruta': 82047, 'lhdi_2018_pred': 40.8}
# {'_id': ObjectId('61d20d53d9221e342731fbb2'), 'siruta': 134942, 'lhdi_2018_pred': 53.5}
# {'_id': ObjectId('61d20d53d9221e342731fbb3'), 'siruta': 13757, 'lhdi_2018_pred': 67.8}
# {'_id': ObjectId('61d20d53d9221e342731fbb4'), 'siruta': 111685, 'lhdi_2018_pred': 38.3}
# {'_id': ObjectId('61d20d53d9221e342731fbb5'), 'siruta': 80249, 'lhdi_2018_pred': 42.2}
# {'_id': ObjectId('61d20d53d9221e342731fbb6'), 'siruta': 103960, 'lhdi_2018_pred': 39.5}
# {'_id': ObjectId('61d20d53d9221e342731fbb7'), 'siruta': 66198, 'lhdi_2018_pred': 54.5}
# {'_id': ObjectId('61d20d53d9221e342731fbb8'), 'siruta': 54387, 'lhdi_2018_pred': 43.5}
# {'_id': ObjectId('61d20d53d9221e342731fbb9'), 'siruta': 110688, 'lhdi_2018_pred': 36.1372489202}
# {'_id': ObjectId('61d20d53d9221e342731fbba'), 'siruta': 80043, 'lhdi_2018_pred': 42.3}
# {'_id': ObjectId('61d20d53d9221e342731fbbb'), 'siruta': 69250, 'lhdi_2018_pred': 57.8}
# {'_id': ObjectId('61d20d53d9221e342731fbbc'), 'siruta': 81816, 'lhdi_2018_pred': 48.3}
# {'_id': ObjectId('61d20d53d9221e342731fbbd'), 'siruta': 135146, 'lhdi_2018_pred': 43.8}
# {'_id': ObjectId('61d20d53d9221e342731fbbe'), 'siruta': 82831, 'lhdi_2018_pred': 41.9}
# {'_id': ObjectId('61d20d53d9221e342731fbbf'), 'siruta': 136241, 'lhdi_2018_pred': 50.9}
# {'_id': ObjectId('61d20d53d9221e342731fbc0'), 'siruta': 66580, 'lhdi_2018_pred': 41.7}
# {'_id': ObjectId('61d20d53d9221e342731fbc1'), 'siruta': 44435, 'lhdi_2018_pred': 41.5}
# {'_id': ObjectId('61d20d53d9221e342731fbc2'), 'siruta': 132681, 'lhdi_2018_pred': 53.2}
# {'_id': ObjectId('61d20d53d9221e342731fbc3'), 'siruta': 170872, 'lhdi_2018_pred': 35.9}
# {'_id': ObjectId('61d20d53d9221e342731fbc4'), 'siruta': 42824, 'lhdi_2018_pred': 39.6}
# {'_id': ObjectId('61d20d53d9221e342731fbc5'), 'siruta': 42968, 'lhdi_2018_pred': 35.1}
# {'_id': ObjectId('61d20d53d9221e342731fbc6'), 'siruta': 129503, 'lhdi_2018_pred': 17.8872298693}
# {'_id': ObjectId('61d20d53d9221e342731fbc7'), 'siruta': 79585, 'lhdi_2018_pred': 49.5}
# {'_id': ObjectId('61d20d53d9221e342731fbc8'), 'siruta': 46910, 'lhdi_2018_pred': 52.1}
# {'_id': ObjectId('61d20d53d9221e342731fbc9'), 'siruta': 54163, 'lhdi_2018_pred': 29.6}
# {'_id': ObjectId('61d20d53d9221e342731fbca'), 'siruta': 49439, 'lhdi_2018_pred': 40.1}
# {'_id': ObjectId('61d20d53d9221e342731fbcb'), 'siruta': 18242, 'lhdi_2018_pred': 52.1}
# {'_id': ObjectId('61d20d53d9221e342731fbcc'), 'siruta': 129914, 'lhdi_2018_pred': 25.8}
# {'_id': ObjectId('61d20d53d9221e342731fbcd'), 'siruta': 112263, 'lhdi_2018_pred': 31}
# {'_id': ObjectId('61d20d53d9221e342731fbce'), 'siruta': 15554, 'lhdi_2018_pred': 17}
# {'_id': ObjectId('61d20d53d9221e342731fbcf'), 'siruta': 113698, 'lhdi_2018_pred': 45.1}
# {'_id': ObjectId('61d20d53d9221e342731fbd0'), 'siruta': 53513, 'lhdi_2018_pred': 50.5}
# {'_id': ObjectId('61d20d53d9221e342731fbd1'), 'siruta': 135020, 'lhdi_2018_pred': 47.3}
# {'_id': ObjectId('61d20d53d9221e342731fbd2'), 'siruta': 82243, 'lhdi_2018_pred': 43.1}
# {'_id': ObjectId('61d20d53d9221e342731fbd3'), 'siruta': 78141, 'lhdi_2018_pred': 59.2}
# {'_id': ObjectId('61d20d53d9221e342731fbd4'), 'siruta': 133018, 'lhdi_2018_pred': 41.9}
# {'_id': ObjectId('61d20d53d9221e342731fbd5'), 'siruta': 80846, 'lhdi_2018_pred': 58}
# {'_id': ObjectId('61d20d53d9221e342731fbd6'), 'siruta': 171806, 'lhdi_2018_pred': 40.3}
# {'_id': ObjectId('61d20d53d9221e342731fbd7'), 'siruta': 130712, 'lhdi_2018_pred': 72.4}
# {'_id': ObjectId('61d20d53d9221e342731fbd8'), 'siruta': 66731, 'lhdi_2018_pred': 60.6}
# {'_id': ObjectId('61d20d53d9221e342731fbd9'), 'siruta': 43812, 'lhdi_2018_pred': 43.6}
# {'_id': ObjectId('61d20d53d9221e342731fbda'), 'siruta': 172947, 'lhdi_2018_pred': 37.7}
# {'_id': ObjectId('61d20d53d9221e342731fbdb'), 'siruta': 133090, 'lhdi_2018_pred': 43.1}
# {'_id': ObjectId('61d20d53d9221e342731fbdc'), 'siruta': 66474, 'lhdi_2018_pred': 54.2}
# {'_id': ObjectId('61d20d53d9221e342731fbdd'), 'siruta': 170685, 'lhdi_2018_pred': 46}
# {'_id': ObjectId('61d20d53d9221e342731fbde'), 'siruta': 130552, 'lhdi_2018_pred': 63.8}
# {'_id': ObjectId('61d20d53d9221e342731fbdf'), 'siruta': 134194, 'lhdi_2018_pred': 50.8}
# {'_id': ObjectId('61d20d53d9221e342731fbe0'), 'siruta': 65501, 'lhdi_2018_pred': 67.8}
# {'_id': ObjectId('61d20d53d9221e342731fbe1'), 'siruta': 46867, 'lhdi_2018_pred': 40.1}
# {'_id': ObjectId('61d20d53d9221e342731fbe2'), 'siruta': 78828, 'lhdi_2018_pred': 68.3}
# {'_id': ObjectId('61d20d53d9221e342731fbe3'), 'siruta': 132379, 'lhdi_2018_pred': 47.9}
# {'_id': ObjectId('61d20d53d9221e342731fbe4'), 'siruta': 170514, 'lhdi_2018_pred': 57.6}
# {'_id': ObjectId('61d20d53d9221e342731fbe5'), 'siruta': 54109, 'lhdi_2018_pred': 45.2}
# {'_id': ObjectId('61d20d53d9221e342731fbe6'), 'siruta': 42842, 'lhdi_2018_pred': 41.6}
# {'_id': ObjectId('61d20d53d9221e342731fbe7'), 'siruta': 52570, 'lhdi_2018_pred': 49.3}
# {'_id': ObjectId('61d20d53d9221e342731fbe8'), 'siruta': 67675, 'lhdi_2018_pred': 44.5}
# {'_id': ObjectId('61d20d53d9221e342731fbe9'), 'siruta': 130892, 'lhdi_2018_pred': 63.8}
# {'_id': ObjectId('61d20d53d9221e342731fbea'), 'siruta': 14085, 'lhdi_2018_pred': 52.7}
# {'_id': ObjectId('61d20d53d9221e342731fbeb'), 'siruta': 172279, 'lhdi_2018_pred': 28.8}
# {'_id': ObjectId('61d20d53d9221e342731fbec'), 'siruta': 78454, 'lhdi_2018_pred': 65.3}
# {'_id': ObjectId('61d20d53d9221e342731fbed'), 'siruta': 48138, 'lhdi_2018_pred': 47}
# {'_id': ObjectId('61d20d53d9221e342731fbee'), 'siruta': 67407, 'lhdi_2018_pred': 52.8}
# {'_id': ObjectId('61d20d53d9221e342731fbef'), 'siruta': 15652, 'lhdi_2018_pred': 22.5}
# {'_id': ObjectId('61d20d53d9221e342731fbf0'), 'siruta': 80613, 'lhdi_2018_pred': 40.4}
# ...
# {'_id': ObjectId('61d20d53d9221e3427320584'), 'siruta': 106461, 'lhdi_2018_pred': 66.1}
# {'_id': ObjectId('61d20d53d9221e3427320585'), 'siruta': 106318, 'lhdi_2018_pred': 67.1}
# {'_id': ObjectId('61d20d53d9221e3427320586'), 'siruta': 106407, 'lhdi_2018_pred': 70.6}
# {'_id': ObjectId('61d20d53d9221e3427320587'), 'siruta': 178279, 'lhdi_2018_pred': 50.1}
# {'_id': ObjectId('61d20d53d9221e3427320588'), 'siruta': 175885, 'lhdi_2018_pred': 53.5}
# {'_id': ObjectId('61d20d53d9221e3427320589'), 'siruta': 175983, 'lhdi_2018_pred': 37.6}
# {'_id': ObjectId('61d20d53d9221e342732058a'), 'siruta': 176338, 'lhdi_2018_pred': 26.6}
# {'_id': ObjectId('61d20d53d9221e342732058b'), 'siruta': 174922, 'lhdi_2018_pred': 48.5}
# {'_id': ObjectId('61d20d53d9221e342732058c'), 'siruta': 176793, 'lhdi_2018_pred': 39.2}
# {'_id': ObjectId('61d20d53d9221e342732058d'), 'siruta': 55106, 'lhdi_2018_pred': 61.1}
# {'_id': ObjectId('61d20d53d9221e342732058e'), 'siruta': 55008, 'lhdi_2018_pred': 68.6}
# {'_id': ObjectId('61d20d53d9221e342732058f'), 'siruta': 55277, 'lhdi_2018_pred': 66.4}
# {'_id': ObjectId('61d20d53d9221e3427320590'), 'siruta': 55259, 'lhdi_2018_pred': 63.9}
# {'_id': ObjectId('61d20d53d9221e3427320591'), 'siruta': 58721, 'lhdi_2018_pred': 59.4}
# {'_id': ObjectId('61d20d53d9221e3427320592'), 'siruta': 57163, 'lhdi_2018_pred': 50.3}
# {'_id': ObjectId('61d20d53d9221e3427320593'), 'siruta': 60026, 'lhdi_2018_pred': 45.2096775071}
# {'_id': ObjectId('61d20d53d9221e3427320594'), 'siruta': 55918, 'lhdi_2018_pred': 47.5}
# {'_id': ObjectId('61d20d53d9221e3427320595'), 'siruta': 60062, 'lhdi_2018_pred': 62}
# {'_id': ObjectId('61d20d53d9221e3427320596'), 'siruta': 59693, 'lhdi_2018_pred': 57.8}
# {'_id': ObjectId('61d20d53d9221e3427320597'), 'siruta': 179347, 'lhdi_2018_pred': 69.6}
# {'_id': ObjectId('61d20d53d9221e3427320598'), 'siruta': 12938, 'lhdi_2018_pred': 64.7}
# {'_id': ObjectId('61d20d53d9221e3427320599'), 'siruta': 10827, 'lhdi_2018_pred': 53}
# {'_id': ObjectId('61d20d53d9221e342732059a'), 'siruta': 103014, 'lhdi_2018_pred': 46.4}
# {'_id': ObjectId('61d20d53d9221e342732059b'), 'siruta': 179515, 'lhdi_2018_pred': 75.5}
# {'_id': ObjectId('61d20d53d9221e342732059c'), 'siruta': 89151, 'lhdi_2018_pred': 54.7080677732}
# {'_id': ObjectId('61d20d53d9221e342732059d'), 'siruta': 90066, 'lhdi_2018_pred': 50.0872302029}
# {'_id': ObjectId('61d20d53d9221e342732059e'), 'siruta': 10453, 'lhdi_2018_pred': 47.7}
# {'_id': ObjectId('61d20d53d9221e342732059f'), 'siruta': 104047, 'lhdi_2018_pred': 29.7}
# {'_id': ObjectId('61d20d53d9221e34273205a0'), 'siruta': 22111, 'lhdi_2018_pred': 27.8}
# {'_id': ObjectId('61d20d53d9221e34273205a1'), 'siruta': 60598, 'lhdi_2018_pred': 59.4}
# {'_id': ObjectId('61d20d53d9221e34273205a2'), 'siruta': 95471, 'lhdi_2018_pred': 60.4}
# {'_id': ObjectId('61d20d53d9221e34273205a3'), 'siruta': 42708, 'lhdi_2018_pred': 67.7}
# {'_id': ObjectId('61d20d53d9221e34273205a4'), 'siruta': 42682, 'lhdi_2018_pred': 61.7}
# {'_id': ObjectId('61d20d53d9221e34273205a5'), 'siruta': 155591, 'lhdi_2018_pred': 57.1}
# {'_id': ObjectId('61d20d53d9221e34273205a6'), 'siruta': 159491, 'lhdi_2018_pred': 51.7}
# {'_id': ObjectId('61d20d53d9221e34273205a7'), 'siruta': 124206, 'lhdi_2018_pred': 45.3}
# {'_id': ObjectId('61d20d53d9221e34273205a8'), 'siruta': 100335, 'lhdi_2018_pred': 47.1}
# {'_id': ObjectId('61d20d53d9221e34273205a9'), 'siruta': 167794, 'lhdi_2018_pred': 48.7}
# {'_id': ObjectId('61d20d53d9221e34273205aa'), 'siruta': 167696, 'lhdi_2018_pred': 65.5}
# {'_id': ObjectId('61d20d53d9221e34273205ab'), 'siruta': 151763, 'lhdi_2018_pred': 43.6}
# {'_id': ObjectId('61d20d53d9221e34273205ac'), 'siruta': 154736, 'lhdi_2018_pred': 40.3}
# {'_id': ObjectId('61d20d53d9221e34273205ad'), 'siruta': 151683, 'lhdi_2018_pred': 52.7}
# {'_id': ObjectId('61d20d53d9221e34273205ae'), 'siruta': 141447, 'lhdi_2018_pred': 45.1}
# {'_id': ObjectId('61d20d53d9221e34273205af'), 'siruta': 140146, 'lhdi_2018_pred': 45.8}
# {'_id': ObjectId('61d20d53d9221e34273205b0'), 'siruta': 174085, 'lhdi_2018_pred': 41}
# {'_id': ObjectId('61d20d53d9221e34273205b1'), 'siruta': 169681, 'lhdi_2018_pred': 36}
# {'_id': ObjectId('61d20d53d9221e34273205b2'), 'siruta': 131461, 'lhdi_2018_pred': 48.8}
# {'_id': ObjectId('61d20d53d9221e34273205b3'), 'siruta': 159437, 'lhdi_2018_pred': 72.7}
# {'_id': ObjectId('61d20d53d9221e34273205b4'), 'siruta': 131103, 'lhdi_2018_pred': 65.7}
# {'_id': ObjectId('61d20d53d9221e34273205b5'), 'siruta': 102909, 'lhdi_2018_pred': 43.8}
# {'_id': ObjectId('61d20d53d9221e34273205b6'), 'siruta': 100521, 'lhdi_2018_pred': 62.4}
# {'_id': ObjectId('61d20d53d9221e34273205b7'), 'siruta': 115637, 'lhdi_2018_pred': 48.7}
# {'_id': ObjectId('61d20d53d9221e34273205b8'), 'siruta': 60419, 'lhdi_2018_pred': 73.4}
# {'_id': ObjectId('61d20d53d9221e34273205b9'), 'siruta': 63198, 'lhdi_2018_pred': 37.9}
# {'_id': ObjectId('61d20d53d9221e34273205ba'), 'siruta': 152902, 'lhdi_2018_pred': 40.7}
# {'_id': ObjectId('61d20d53d9221e34273205bb'), 'siruta': 154834, 'lhdi_2018_pred': 41.8}
# {'_id': ObjectId('61d20d53d9221e34273205bc'), 'siruta': 62672, 'lhdi_2018_pred': 47.3}
# {'_id': ObjectId('61d20d53d9221e34273205bd'), 'siruta': 60721, 'lhdi_2018_pred': 60.2}
# {'_id': ObjectId('61d20d53d9221e34273205be'), 'siruta': 63334, 'lhdi_2018_pred': 55.2}
# {'_id': ObjectId('61d20d53d9221e34273205bf'), 'siruta': 107001, 'lhdi_2018_pred': 49.4}
# {'_id': ObjectId('61d20d53d9221e34273205c0'), 'siruta': 82555, 'lhdi_2018_pred': 48.9}
# {'_id': ObjectId('61d20d53d9221e34273205c1'), 'siruta': 78926, 'lhdi_2018_pred': 37.1}
# {'_id': ObjectId('61d20d53d9221e34273205c2'), 'siruta': 91937, 'lhdi_2018_pred': 39.1}
# {'_id': ObjectId('61d20d53d9221e34273205c3'), 'siruta': 90208, 'lhdi_2018_pred': 48.5}
# {'_id': ObjectId('61d20d53d9221e34273205c4'), 'siruta': 54975, 'lhdi_2018_pred': 80.1}
# {'_id': ObjectId('61d20d53d9221e34273205c5'), 'siruta': 155109, 'lhdi_2018_pred': 36.8}
# {'_id': ObjectId('61d20d53d9221e34273205c6'), 'siruta': 153829, 'lhdi_2018_pred': 40.8}
# {'_id': ObjectId('61d20d53d9221e34273205c7'), 'siruta': 25488, 'lhdi_2018_pred': 47}
# {'_id': ObjectId('61d20d53d9221e34273205c8'), 'siruta': 24338, 'lhdi_2018_pred': 34.6}
# {'_id': ObjectId('61d20d53d9221e34273205c9'), 'siruta': 178938, 'lhdi_2018_pred': 46.2}
# {'_id': ObjectId('61d20d53d9221e34273205ca'), 'siruta': 178956, 'lhdi_2018_pred': 52.3}
# {'_id': ObjectId('61d20d53d9221e34273205cb'), 'siruta': 42058, 'lhdi_2018_pred': 48.5}
# {'_id': ObjectId('61d20d53d9221e34273205cc'), 'siruta': 64265, 'lhdi_2018_pred': 48.2}
# {'_id': ObjectId('61d20d53d9221e34273205cd'), 'siruta': 83375, 'lhdi_2018_pred': 64.4}
# {'_id': ObjectId('61d20d53d9221e34273205ce'), 'siruta': 96254, 'lhdi_2018_pred': 60.3}
# {'_id': ObjectId('61d20d53d9221e34273205cf'), 'siruta': 97919, 'lhdi_2018_pred': 78}
# {'_id': ObjectId('61d20d53d9221e34273205d0'), 'siruta': 18162, 'lhdi_2018_pred': 35.4}
# {'_id': ObjectId('61d20d53d9221e34273205d1'), 'siruta': 16739, 'lhdi_2018_pred': 44.8}
# {'_id': ObjectId('61d20d53d9221e34273205d2'), 'siruta': 66857, 'lhdi_2018_pred': 36.2}
# {'_id': ObjectId('61d20d53d9221e34273205d3'), 'siruta': 153062, 'lhdi_2018_pred': 41.9}
# {'_id': ObjectId('61d20d53d9221e34273205d4'), 'siruta': 154308, 'lhdi_2018_pred': 39.3}
# {'_id': ObjectId('61d20d53d9221e34273205d5'), 'siruta': 60455, 'lhdi_2018_pred': 74.1}
# {'_id': ObjectId('61d20d53d9221e34273205d6'), 'siruta': 120487, 'lhdi_2018_pred': 82.3}
# {'_id': ObjectId('61d20d53d9221e34273205d7'), 'siruta': 114319, 'lhdi_2018_pred': 72.2}
# {'_id': ObjectId('61d20d53d9221e34273205d8'), 'siruta': 119723, 'lhdi_2018_pred': 58.4}
# {'_id': ObjectId('61d20d53d9221e34273205d9'), 'siruta': 114809, 'lhdi_2018_pred': 67}
# {'_id': ObjectId('61d20d53d9221e34273205da'), 'siruta': 60632, 'lhdi_2018_pred': 65.6}
# {'_id': ObjectId('61d20d53d9221e34273205db'), 'siruta': 60482, 'lhdi_2018_pred': 70.7}
# {'_id': ObjectId('61d20d53d9221e34273205dc'), 'siruta': 62985, 'lhdi_2018_pred': 57.7}
# {'_id': ObjectId('61d20d53d9221e34273205dd'), 'siruta': 63326, 'lhdi_2018_pred': 52.7}
# {'_id': ObjectId('61d20d53d9221e34273205de'), 'siruta': 61372, 'lhdi_2018_pred': 63.4}
# {'_id': ObjectId('61d20d53d9221e34273205df'), 'siruta': 148202, 'lhdi_2018_pred': 53.6}
# {'_id': ObjectId('61d20d53d9221e34273205e0'), 'siruta': 32153, 'lhdi_2018_pred': 55.7}
# {'_id': ObjectId('61d20d53d9221e34273205e1'), 'siruta': 77377, 'lhdi_2018_pred': 43.2}
# {'_id': ObjectId('61d20d53d9221e34273205e2'), 'siruta': 76497, 'lhdi_2018_pred': 35.6}
# {'_id': ObjectId('61d20d53d9221e34273205e3'), 'siruta': 39975, 'lhdi_2018_pred': 26.9}
# {'_id': ObjectId('61d20d53d9221e34273205e4'), 'siruta': 36300, 'lhdi_2018_pred': 33.8}
# {'_id': ObjectId('61d20d53d9221e34273205e5'), 'siruta': 155760, 'lhdi_2018_pred': 62.7}
# {'_id': ObjectId('61d20d53d9221e34273205e6'), 'siruta': 159384, 'lhdi_2018_pred': 65.5}
# {'_id': ObjectId('61d20d53d9221e34273205e7'), 'siruta': 72007, 'lhdi_2018_pred': 44.7}
# {'_id': ObjectId('61d20d53d9221e34273205e8'), 'siruta': 70637, 'lhdi_2018_pred': 42.1}
# {'_id': ObjectId('61d20d53d9221e34273205e9'), 'siruta': 71340, 'lhdi_2018_pred': 50.4}
# {'_id': ObjectId('61d20d53d9221e34273205ea'), 'siruta': 126674, 'lhdi_2018_pred': 20.7}
# {'_id': ObjectId('61d20d53d9221e34273205eb'), 'siruta': 127288, 'lhdi_2018_pred': 40.8}
# {'_id': ObjectId('61d20d53d9221e34273205ec'), 'siruta': 105160, 'lhdi_2018_pred': 81.5}
# {'_id': ObjectId('61d20d53d9221e34273205ed'), 'siruta': 103513, 'lhdi_2018_pred': 66.3}
# {'_id': ObjectId('61d20d53d9221e34273205ee'), 'siruta': 103997, 'lhdi_2018_pred': 81.6}
# {'_id': ObjectId('61d20d53d9221e34273205ef'), 'siruta': 101957, 'lhdi_2018_pred': 80}
# {'_id': ObjectId('61d20d53d9221e34273205f0'), 'siruta': 179409, 'lhdi_2018_pred': 82.6}
# {'_id': ObjectId('61d20d53d9221e34273205f1'), 'siruta': 40900, 'lhdi_2018_pred': 84.8}
# {'_id': ObjectId('61d20d53d9221e34273205f2'), 'siruta': 40198, 'lhdi_2018_pred': 73.6}
# {'_id': ObjectId('61d20d53d9221e34273205f3'), 'siruta': 20297, 'lhdi_2018_pred': 62.3}
# {'_id': ObjectId('61d20d53d9221e34273205f4'), 'siruta': 20359, 'lhdi_2018_pred': 57.6}
# {'_id': ObjectId('61d20d53d9221e34273205f5'), 'siruta': 32394, 'lhdi_2018_pred': 70.9}
# {'_id': ObjectId('61d20d53d9221e34273205f6'), 'siruta': 33729, 'lhdi_2018_pred': 54.7}
# {'_id': ObjectId('61d20d53d9221e34273205f7'), 'siruta': 33621, 'lhdi_2018_pred': 59.9}
# {'_id': ObjectId('61d20d53d9221e34273205f8'), 'siruta': 34333, 'lhdi_2018_pred': 52.8}
# {'_id': ObjectId('61d20d53d9221e34273205f9'), 'siruta': 148916, 'lhdi_2018_pred': 45.8}
# {'_id': ObjectId('61d20d53d9221e34273205fa'), 'siruta': 146995, 'lhdi_2018_pred': 37.7}
# {'_id': ObjectId('61d20d53d9221e34273205fb'), 'siruta': 43493, 'lhdi_2018_pred': 28.8}
# {'_id': ObjectId('61d20d53d9221e34273205fc'), 'siruta': 18331, 'lhdi_2018_pred': 46.1}
# {'_id': ObjectId('61d20d53d9221e34273205fd'), 'siruta': 15233, 'lhdi_2018_pred': 66.2}
# {'_id': ObjectId('61d20d53d9221e34273205fe'), 'siruta': 18475, 'lhdi_2018_pred': 48.3}
# {'_id': ObjectId('61d20d53d9221e34273205ff'), 'siruta': 150310, 'lhdi_2018_pred': 40.1}
# {'_id': ObjectId('61d20d53d9221e3427320600'), 'siruta': 151567, 'lhdi_2018_pred': 26.6}
# {'_id': ObjectId('61d20d53d9221e3427320601'), 'siruta': 148328, 'lhdi_2018_pred': 24.6}
# {'_id': ObjectId('61d20d53d9221e3427320602'), 'siruta': 147134, 'lhdi_2018_pred': 52.5}
# {'_id': ObjectId('61d20d53d9221e3427320603'), 'siruta': 149414, 'lhdi_2018_pred': 48.1}
# {'_id': ObjectId('61d20d53d9221e3427320604'), 'siruta': 146432, 'lhdi_2018_pred': 69}
# {'_id': ObjectId('61d20d53d9221e3427320605'), 'siruta': 149833, 'lhdi_2018_pred': 38.1}
# {'_id': ObjectId('61d20d53d9221e3427320606'), 'siruta': 146325, 'lhdi_2018_pred': 44.9}
# {'_id': ObjectId('61d20d53d9221e3427320607'), 'siruta': 146370, 'lhdi_2018_pred': 52.2}
# {'_id': ObjectId('61d20d53d9221e3427320608'), 'siruta': 146281, 'lhdi_2018_pred': 67.1}
# {'_id': ObjectId('61d20d53d9221e3427320609'), 'siruta': 146263, 'lhdi_2018_pred': 66.6}
# {'_id': ObjectId('61d20d53d9221e342732060a'), 'siruta': 161464, 'lhdi_2018_pred': 47.5}
# {'_id': ObjectId('61d20d53d9221e342732060b'), 'siruta': 160430, 'lhdi_2018_pred': 47.4}
# {'_id': ObjectId('61d20d53d9221e342732060c'), 'siruta': 11539, 'lhdi_2018_pred': 58.8}
# {'_id': ObjectId('61d20d53d9221e342732060d'), 'siruta': 152350, 'lhdi_2018_pred': 28.8}
# {'_id': ObjectId('61d20d53d9221e342732060e'), 'siruta': 97465, 'lhdi_2018_pred': 19.7}
# {'_id': ObjectId('61d20d53d9221e342732060f'), 'siruta': 75864, 'lhdi_2018_pred': 32.8}
# {'_id': ObjectId('61d20d53d9221e3427320610'), 'siruta': 75356, 'lhdi_2018_pred': 36.1}
# {'_id': ObjectId('61d20d53d9221e3427320611'), 'siruta': 52909, 'lhdi_2018_pred': 6.9}
# {'_id': ObjectId('61d20d53d9221e3427320612'), 'siruta': 51056, 'lhdi_2018_pred': 52.4}
# {'_id': ObjectId('61d20d53d9221e3427320613'), 'siruta': 155261, 'lhdi_2018_pred': 96.5}
# {'_id': ObjectId('61d20d53d9221e3427320614'), 'siruta': 77475, 'lhdi_2018_pred': 46.7}
# {'_id': ObjectId('61d20d53d9221e3427320615'), 'siruta': 75953, 'lhdi_2018_pred': 47}
# {'_id': ObjectId('61d20d53d9221e3427320616'), 'siruta': 61871, 'lhdi_2018_pred': 36}
# {'_id': ObjectId('61d20d53d9221e3427320617'), 'siruta': 146904, 'lhdi_2018_pred': 38.8}
# {'_id': ObjectId('61d20d53d9221e3427320618'), 'siruta': 147786, 'lhdi_2018_pred': 39.8}
# {'_id': ObjectId('61d20d53d9221e3427320619'), 'siruta': 149502, 'lhdi_2018_pred': 30.6}
# {'_id': ObjectId('61d20d53d9221e342732061a'), 'siruta': 149101, 'lhdi_2018_pred': 46.1}
# {'_id': ObjectId('61d20d53d9221e342732061b'), 'siruta': 151479, 'lhdi_2018_pred': 43.8}
# {'_id': ObjectId('61d20d53d9221e342732061c'), 'siruta': 148667, 'lhdi_2018_pred': 38.5}
# {'_id': ObjectId('61d20d53d9221e342732061d'), 'siruta': 149584, 'lhdi_2018_pred': 16}
# {'_id': ObjectId('61d20d53d9221e342732061e'), 'siruta': 151095, 'lhdi_2018_pred': 42.2}
# {'_id': ObjectId('61d20d53d9221e342732061f'), 'siruta': 150043, 'lhdi_2018_pred': 45.3}
# {'_id': ObjectId('61d20d53d9221e3427320620'), 'siruta': 146628, 'lhdi_2018_pred': 64.9}
# {'_id': ObjectId('61d20d53d9221e3427320621'), 'siruta': 147161, 'lhdi_2018_pred': 43.8}
# {'_id': ObjectId('61d20d53d9221e3427320622'), 'siruta': 147526, 'lhdi_2018_pred': 43.7}
# {'_id': ObjectId('61d20d53d9221e3427320623'), 'siruta': 147358, 'lhdi_2018_pred': 49.3}
# {'_id': ObjectId('61d20d53d9221e3427320624'), 'siruta': 147884, 'lhdi_2018_pred': 45.5}
# {'_id': ObjectId('61d20d53d9221e3427320625'), 'siruta': 111220, 'lhdi_2018_pred': 42.0117639549}
# {'_id': ObjectId('61d20d53d9221e3427320626'), 'siruta': 179221, 'lhdi_2018_pred': 84.1}
# {'_id': ObjectId('61d20d53d9221e3427320627'), 'siruta': 147633, 'lhdi_2018_pred': 25.5}
# {'_id': ObjectId('61d20d53d9221e3427320628'), 'siruta': 146931, 'lhdi_2018_pred': 49.2}
# {'_id': ObjectId('61d20d53d9221e3427320629'), 'siruta': 103443, 'lhdi_2018_pred': 62}
# {'_id': ObjectId('61d20d53d9221e342732062a'), 'siruta': 104582, 'lhdi_2018_pred': 54.7}
# {'_id': ObjectId('61d20d53d9221e342732062b'), 'siruta': 164197, 'lhdi_2018_pred': 25.8}
# {'_id': ObjectId('61d20d53d9221e342732062c'), 'siruta': 164277, 'lhdi_2018_pred': 29}
# {'_id': ObjectId('61d20d53d9221e342732062d'), 'siruta': 51840, 'lhdi_2018_pred': 30.7503770577}
# {'_id': ObjectId('61d20d53d9221e342732062e'), 'siruta': 66081, 'lhdi_2018_pred': 67.5}
# {'_id': ObjectId('61d20d53d9221e342732062f'), 'siruta': 66152, 'lhdi_2018_pred': 46.1}
# {'_id': ObjectId('61d20d53d9221e3427320630'), 'siruta': 91688, 'lhdi_2018_pred': 57.6}
# {'_id': ObjectId('61d20d53d9221e3427320631'), 'siruta': 87638, 'lhdi_2018_pred': 65.2}
# {'_id': ObjectId('61d20d53d9221e3427320632'), 'siruta': 80766, 'lhdi_2018_pred': 35.2}
# {'_id': ObjectId('61d20d53d9221e3427320633'), 'siruta': 155494, 'lhdi_2018_pred': 66}
# {'_id': ObjectId('61d20d53d9221e3427320634'), 'siruta': 157451, 'lhdi_2018_pred': 56.9}
# {'_id': ObjectId('61d20d53d9221e3427320635'), 'siruta': 60570, 'lhdi_2018_pred': 75.1}
# {'_id': ObjectId('61d20d53d9221e3427320636'), 'siruta': 60534, 'lhdi_2018_pred': 65.3}
# {'_id': ObjectId('61d20d53d9221e3427320637'), 'siruta': 179711, 'lhdi_2018_pred': 50.6}
# {'_id': ObjectId('61d20d53d9221e3427320638'), 'siruta': 67256, 'lhdi_2018_pred': 52.5}
# {'_id': ObjectId('61d20d53d9221e3427320639'), 'siruta': 179132, 'lhdi_2018_pred': 74.9}

# %%
# Create a pandas DataFrame with the data in the last cursor
lhdi_list = []
cursor = db.lhdi_2018_pred.find({})
for item in cursor:
    lhdi_list.append(item)
lhdi_2018_pred = pd.DataFrame(lhdi_list)

# %%
lhdi_2018_pred.head()
# Out:
#                         _id  siruta  lhdi_2018_pred
# 0  61d20d53d9221e342731f9cd  153400            41.0
# 1  61d20d53d9221e342731f9ce  152314            40.0
# 2  61d20d53d9221e342731f9cf  151978            57.8
# 3  61d20d53d9221e342731f9d0  151709            39.9
# 4  61d20d53d9221e342731f9d1  155118            50.0

# %% [markdown]
# Gather some more data, this time from an official covid-19 API

# %%
# Store the endpoint in a new variable
endpoint = 'https://covid19.geo-spatial.org/api/dashboard/getCasesByCounty'

# %%
response = requests.get(endpoint)
response
# Out:
# <Response [200]>

# %%
covid_data = response.json()
covid_data
# Out:
# {'data': {'total': 49591,
#   'data': [{'county_code': 'B',
#     'total_county': 4784,
#     'total_healed': 6,
#     'total_dead': 105,
#     'county': 'BUCUREȘTI'},
#    {'county_code': 'SV',
#     'total_county': 4114,
#     'total_healed': 5,
#     'total_dead': 242,
#     'county': 'SUCEAVA'},
#    {'county_code': 'AG',
#     'total_county': 2656,
#     'total_healed': 0,
#     'total_dead': 95,
#     'county': 'ARGEȘ'},
#    {'county_code': 'BV',
#     'total_county': 2629,
#     'total_healed': 0,
#     'total_dead': 60,
#     'county': 'BRAȘOV'},
#    {'county_code': 'GL',
#     'total_county': 1784,
#     'total_healed': 0,
#     'total_dead': 92,
#     'county': 'GALAȚI'},
#    {'county_code': 'DB',
#     'total_county': 1577,
#     'total_healed': 6,
#     'total_dead': 18,
#     'county': 'DÂMBOVIȚA'},
#    {'county_code': 'PH',
#     'total_county': 1559,
#     'total_healed': 0,
#     'total_dead': 39,
#     'county': 'PRAHOVA'},
#    {'county_code': 'VN',
#     'total_county': 1535,
#     'total_healed': 0,
#     'total_dead': 46,
#     'county': 'VRANCEA'},
#    {'county_code': 'IS',
#     'total_county': 1328,
#     'total_healed': 1,
#     'total_dead': 42,
#     'county': 'IAȘI'},
#    {'county_code': 'BZ',
#     'total_county': 1142,
#     'total_healed': 0,
#     'total_dead': 11,
#     'county': 'BUZĂU'},
#    {'county_code': 'NT',
#     'total_county': 1125,
#     'total_healed': 0,
#     'total_dead': 55,
#     'county': 'NEAMȚ'},
#    {'county_code': 'NA',
#     'total_county': 1115,
#     'total_healed': 0,
#     'total_dead': 0,
#     'county': 'JUDEȚ NECUNOSCUT'},
#    {'county_code': 'BC',
#     'total_county': 1112,
#     'total_healed': 0,
#     'total_dead': 58,
#     'county': 'BACĂU'},
#    {'county_code': 'BT',
#     'total_county': 1109,
#     'total_healed': 3,
#     'total_dead': 57,
#     'county': 'BOTOȘANI'},
#    {'county_code': 'IF',
#     'total_county': 1106,
#     'total_healed': 0,
#     'total_dead': 23,
#     'county': 'ILFOV'},
#    {'county_code': 'TM',
#     'total_county': 985,
#     'total_healed': 4,
#     'total_dead': 55,
#     'county': 'TIMIȘ'},
#    {'county_code': 'CJ',
#     'total_county': 953,
#     'total_healed': 1,
#     'total_dead': 18,
#     'county': 'CLUJ'},
#    {'county_code': 'MS',
#     'total_county': 895,
#     'total_healed': 0,
#     'total_dead': 67,
#     'county': 'MUREȘ'},
#    {'county_code': 'BH',
#     'total_county': 836,
#     'total_healed': 0,
#     'total_dead': 22,
#     'county': 'BIHOR'},
#    {'county_code': 'HD',
#     'total_county': 811,
#     'total_healed': 3,
#     'total_dead': 72,
#     'county': 'HUNEDOARA'},
#    {'county_code': 'AR',
#     'total_county': 799,
#     'total_healed': 1,
#     'total_dead': 77,
#     'county': 'ARAD'},
#    {'county_code': 'SB',
#     'total_county': 793,
#     'total_healed': 0,
#     'total_dead': 46,
#     'county': 'SIBIU'},
#    {'county_code': 'BN',
#     'total_county': 754,
#     'total_healed': 0,
#     'total_dead': 66,
#     'county': 'BISTRIȚA-NĂSĂUD'},
#    {'county_code': 'CT',
#     'total_county': 728,
#     'total_healed': 2,
#     'total_dead': 19,
#     'county': 'CONSTANȚA'},
#    {'county_code': 'AB',
#     'total_county': 671,
#     'total_healed': 27,
#     'total_dead': 23,
#     'county': 'ALBA'},
#    {'county_code': 'GJ',
#     'total_county': 642,
#     'total_healed': 1,
#     'total_dead': 10,
#     'county': 'GORJ'},
#    {'county_code': 'IL',
#     'total_county': 640,
#     'total_healed': 16,
#     'total_dead': 24,
#     'county': 'IALOMIȚA'},
#    {'county_code': 'BR',
#     'total_county': 615,
#     'total_healed': 0,
#     'total_dead': 4,
#     'county': 'BRĂILA'},
#    {'county_code': 'OT',
#     'total_county': 610,
#     'total_healed': 5,
#     'total_dead': 16,
#     'county': 'OLT'},
#    {'county_code': 'DJ',
#     'total_county': 559,
#     'total_healed': 0,
#     'total_dead': 6,
#     'county': 'DOLJ'},
#    {'county_code': 'MH',
#     'total_county': 516,
#     'total_healed': 0,
#     'total_dead': 22,
#     'county': 'MEHEDINȚI'},
#    {'county_code': 'HR',
#     'total_county': 495,
#     'total_healed': 0,
#     'total_dead': 3,
#     'county': 'HARGHITA'},
#    {'county_code': 'VS',
#     'total_county': 495,
#     'total_healed': 0,
#     'total_dead': 19,
#     'county': 'VASLUI'},
#    {'county_code': 'CV',
#     'total_county': 384,
#     'total_healed': 0,
#     'total_dead': 11,
#     'county': 'COVASNA'},
#    {'county_code': 'VL',
#     'total_county': 343,
#     'total_healed': 0,
#     'total_dead': 4,
#     'county': 'VÂLCEA'},
#    {'county_code': 'GR',
#     'total_county': 337,
#     'total_healed': 0,
#     'total_dead': 6,
#     'county': 'GIURGIU'},
#    {'county_code': 'MM',
#     'total_county': 333,
#     'total_healed': 1,
#     'total_dead': 6,
#     'county': 'MARAMUREȘ'},
#    {'county_code': 'TL',
#     'total_county': 254,
#     'total_healed': 0,
#     'total_dead': 8,
#     'county': 'TULCEA'},
#    {'county_code': 'TR',
#     'total_county': 253,
#     'total_healed': 0,
#     'total_dead': 11,
#     'county': 'TELEORMAN'},
#    {'county_code': 'CL',
#     'total_county': 248,
#     'total_healed': 0,
#     'total_dead': 3,
#     'county': 'CĂLĂRAȘI'},
#    {'county_code': 'CS',
#     'total_county': 188,
#     'total_healed': 6,
#     'total_dead': 7,
#     'county': 'CARAȘ-SEVERIN'},
#    {'county_code': 'SJ',
#     'total_county': 149,
#     'total_healed': 0,
#     'total_dead': 17,
#     'county': 'SĂLAJ'},
#    {'county_code': 'SM',
#     'total_county': 91,
#     'total_healed': 0,
#     'total_dead': 8,
#     'county': 'SATU MARE'}]}}

# %%
# Check the keys of the dictionary
covid_data.keys()
# Out:
# dict_keys(['data'])

# %%
covid_data['data'].keys()
# Out:
# dict_keys(['total', 'data'])

# %%
covid_data['data']['data']
# Out:
# [{'county_code': 'B',
#   'total_county': 4784,
#   'total_healed': 6,
#   'total_dead': 105,
#   'county': 'BUCUREȘTI'},
#  {'county_code': 'SV',
#   'total_county': 4114,
#   'total_healed': 5,
#   'total_dead': 242,
#   'county': 'SUCEAVA'},
#  {'county_code': 'AG',
#   'total_county': 2656,
#   'total_healed': 0,
#   'total_dead': 95,
#   'county': 'ARGEȘ'},
#  {'county_code': 'BV',
#   'total_county': 2629,
#   'total_healed': 0,
#   'total_dead': 60,
#   'county': 'BRAȘOV'},
#  {'county_code': 'GL',
#   'total_county': 1784,
#   'total_healed': 0,
#   'total_dead': 92,
#   'county': 'GALAȚI'},
#  {'county_code': 'DB',
#   'total_county': 1577,
#   'total_healed': 6,
#   'total_dead': 18,
#   'county': 'DÂMBOVIȚA'},
#  {'county_code': 'PH',
#   'total_county': 1559,
#   'total_healed': 0,
#   'total_dead': 39,
#   'county': 'PRAHOVA'},
#  {'county_code': 'VN',
#   'total_county': 1535,
#   'total_healed': 0,
#   'total_dead': 46,
#   'county': 'VRANCEA'},
#  {'county_code': 'IS',
#   'total_county': 1328,
#   'total_healed': 1,
#   'total_dead': 42,
#   'county': 'IAȘI'},
#  {'county_code': 'BZ',
#   'total_county': 1142,
#   'total_healed': 0,
#   'total_dead': 11,
#   'county': 'BUZĂU'},
#  {'county_code': 'NT',
#   'total_county': 1125,
#   'total_healed': 0,
#   'total_dead': 55,
#   'county': 'NEAMȚ'},
#  {'county_code': 'NA',
#   'total_county': 1115,
#   'total_healed': 0,
#   'total_dead': 0,
#   'county': 'JUDEȚ NECUNOSCUT'},
#  {'county_code': 'BC',
#   'total_county': 1112,
#   'total_healed': 0,
#   'total_dead': 58,
#   'county': 'BACĂU'},
#  {'county_code': 'BT',
#   'total_county': 1109,
#   'total_healed': 3,
#   'total_dead': 57,
#   'county': 'BOTOȘANI'},
#  {'county_code': 'IF',
#   'total_county': 1106,
#   'total_healed': 0,
#   'total_dead': 23,
#   'county': 'ILFOV'},
#  {'county_code': 'TM',
#   'total_county': 985,
#   'total_healed': 4,
#   'total_dead': 55,
#   'county': 'TIMIȘ'},
#  {'county_code': 'CJ',
#   'total_county': 953,
#   'total_healed': 1,
#   'total_dead': 18,
#   'county': 'CLUJ'},
#  {'county_code': 'MS',
#   'total_county': 895,
#   'total_healed': 0,
#   'total_dead': 67,
#   'county': 'MUREȘ'},
#  {'county_code': 'BH',
#   'total_county': 836,
#   'total_healed': 0,
#   'total_dead': 22,
#   'county': 'BIHOR'},
#  {'county_code': 'HD',
#   'total_county': 811,
#   'total_healed': 3,
#   'total_dead': 72,
#   'county': 'HUNEDOARA'},
#  {'county_code': 'AR',
#   'total_county': 799,
#   'total_healed': 1,
#   'total_dead': 77,
#   'county': 'ARAD'},
#  {'county_code': 'SB',
#   'total_county': 793,
#   'total_healed': 0,
#   'total_dead': 46,
#   'county': 'SIBIU'},
#  {'county_code': 'BN',
#   'total_county': 754,
#   'total_healed': 0,
#   'total_dead': 66,
#   'county': 'BISTRIȚA-NĂSĂUD'},
#  {'county_code': 'CT',
#   'total_county': 728,
#   'total_healed': 2,
#   'total_dead': 19,
#   'county': 'CONSTANȚA'},
#  {'county_code': 'AB',
#   'total_county': 671,
#   'total_healed': 27,
#   'total_dead': 23,
#   'county': 'ALBA'},
#  {'county_code': 'GJ',
#   'total_county': 642,
#   'total_healed': 1,
#   'total_dead': 10,
#   'county': 'GORJ'},
#  {'county_code': 'IL',
#   'total_county': 640,
#   'total_healed': 16,
#   'total_dead': 24,
#   'county': 'IALOMIȚA'},
#  {'county_code': 'BR',
#   'total_county': 615,
#   'total_healed': 0,
#   'total_dead': 4,
#   'county': 'BRĂILA'},
#  {'county_code': 'OT',
#   'total_county': 610,
#   'total_healed': 5,
#   'total_dead': 16,
#   'county': 'OLT'},
#  {'county_code': 'DJ',
#   'total_county': 559,
#   'total_healed': 0,
#   'total_dead': 6,
#   'county': 'DOLJ'},
#  {'county_code': 'MH',
#   'total_county': 516,
#   'total_healed': 0,
#   'total_dead': 22,
#   'county': 'MEHEDINȚI'},
#  {'county_code': 'HR',
#   'total_county': 495,
#   'total_healed': 0,
#   'total_dead': 3,
#   'county': 'HARGHITA'},
#  {'county_code': 'VS',
#   'total_county': 495,
#   'total_healed': 0,
#   'total_dead': 19,
#   'county': 'VASLUI'},
#  {'county_code': 'CV',
#   'total_county': 384,
#   'total_healed': 0,
#   'total_dead': 11,
#   'county': 'COVASNA'},
#  {'county_code': 'VL',
#   'total_county': 343,
#   'total_healed': 0,
#   'total_dead': 4,
#   'county': 'VÂLCEA'},
#  {'county_code': 'GR',
#   'total_county': 337,
#   'total_healed': 0,
#   'total_dead': 6,
#   'county': 'GIURGIU'},
#  {'county_code': 'MM',
#   'total_county': 333,
#   'total_healed': 1,
#   'total_dead': 6,
#   'county': 'MARAMUREȘ'},
#  {'county_code': 'TL',
#   'total_county': 254,
#   'total_healed': 0,
#   'total_dead': 8,
#   'county': 'TULCEA'},
#  {'county_code': 'TR',
#   'total_county': 253,
#   'total_healed': 0,
#   'total_dead': 11,
#   'county': 'TELEORMAN'},
#  {'county_code': 'CL',
#   'total_county': 248,
#   'total_healed': 0,
#   'total_dead': 3,
#   'county': 'CĂLĂRAȘI'},
#  {'county_code': 'CS',
#   'total_county': 188,
#   'total_healed': 6,
#   'total_dead': 7,
#   'county': 'CARAȘ-SEVERIN'},
#  {'county_code': 'SJ',
#   'total_county': 149,
#   'total_healed': 0,
#   'total_dead': 17,
#   'county': 'SĂLAJ'},
#  {'county_code': 'SM',
#   'total_county': 91,
#   'total_healed': 0,
#   'total_dead': 8,
#   'county': 'SATU MARE'}]

# %%
# Create a pandas DataFrame with the covid data on each county
covid_df = pd.DataFrame(covid_data['data']['data'])
covid_df.head()
# Out:
#   county_code  total_county  total_healed  total_dead     county
# 0           B          4784             6         105  BUCUREȘTI
# 1          SV          4114             5         242    SUCEAVA
# 2          AG          2656             0          95      ARGEȘ
# 3          BV          2629             0          60     BRAȘOV
# 4          GL          1784             0          92     GALAȚI

# %%
# Start preprocessing the dataset by renaming one column
covid_df.rename(columns={'county_code': 'code'}, inplace=True)
covid_df.head()
# Out:
#   code  total_county  total_healed  total_dead     county
# 0    B          4784             6         105  BUCUREȘTI
# 1   SV          4114             5         242    SUCEAVA
# 2   AG          2656             0          95      ARGEȘ
# 3   BV          2629             0          60     BRAȘOV
# 4   GL          1784             0          92     GALAȚI

# %%
'BUCURESTI'.title()
# Out:
# 'Bucuresti'

# %%
# Apply a lambda function to all rows of the county column in order to transform all text using the title() function
covid_df['county'] = covid_df['county'].apply(lambda x: x.title())
covid_df.head()
# Out:
#   code  total_county  total_healed  total_dead     county
# 0    B          4784             6         105  București
# 1   SV          4114             5         242    Suceava
# 2   AG          2656             0          95      Argeș
# 3   BV          2629             0          60     Brașov
# 4   GL          1784             0          92     Galați

# %%
covid_df['county'] = covid_df['county'].apply(
    lambda x: unidecode(x))  # unidecode will convert the diacritics to non-accented letters
covid_df['county'] = covid_df['county'].apply(
    lambda x: x.strip())  # strip is used to strip the string from all extra spaces
covid_df.head()
# Out:
#   code  total_county  total_healed  total_dead     county
# 0    B          4784             6         105  Bucuresti
# 1   SV          4114             5         242    Suceava
# 2   AG          2656             0          95      Arges
# 3   BV          2629             0          60     Brasov
# 4   GL          1784             0          92     Galati

# %%
covid_df.to_csv('Data/covid_df.csv',
                index=False)  # once the dataset is saved, create a new collection and import it to MongoDB

# %%
# Gather data on the active population of each ATU
url = "https://raw.githubusercontent.com/stefanacioban/covid_19_spatial_analysis/main/data/pop_active_2021.csv"
active_pop = pd.read_csv(url)
active_pop.head()
# Out:
#   county  total_pop  siruta            uat  pop_age_0  pop_age_1  pop_age_10  \
# 0   Arad     174244  9262.0           ARAD     1311.0     1510.0      1577.0
# 1   Arad       8113  9459.0  CHISINEU-CRIS       63.0       78.0        68.0
# 2   Arad       8848  9495.0        CURTICI       86.0      104.0       109.0
# 3   Arad       9481  9538.0           INEU       71.0       76.0        93.0
# 4   Arad      11096  9574.0         LIPOVA       74.0       94.0        93.0
#
#    pop_age_11  pop_age_12  pop_age_13  ...  pop_age_79  pop_age_8  pop_age_80  \
# 0      1662.0      1633.0      1597.0  ...         NaN     1522.0         NaN
# 1        70.0        92.0        90.0  ...         NaN       85.0         NaN
# 2        94.0       101.0       110.0  ...         NaN       92.0         NaN
# 3        94.0        98.0        81.0  ...         NaN       92.0         NaN
# 4       105.0        96.0        91.0  ...         NaN      104.0         NaN
#
#    pop_age_81  pop_age_82  pop_age_83  pop_age_84  pop_age_85  pop_age_9  \
# 0         NaN         NaN         NaN         NaN        2985     1510.0
# 1         NaN         NaN         NaN         NaN         114       59.0
# 2         NaN         NaN         NaN         NaN         108       98.0
# 3         NaN         NaN         NaN         NaN         124       91.0
# 4         NaN         NaN         NaN         NaN         203       91.0
#
#    pop_age_18_62
# 0       108795.0
# 1         5010.0
# 2         5476.0
# 3         5839.0
# 4         6942.0
#
# [5 rows x 91 columns]

# %% [markdown]
# This data was gathered from [The Natinoal Institue of Statistics Romania (2020)](http://statistici.insse.ro/) and it contains the active population (population between 18 and 62 years).

# %%
# Preprocess the active_pop dataframe
active_pop = active_pop[['county', 'total_pop', 'siruta', 'uat', 'pop_age_18_62']]  # subset the initial dataframe
active_pop.head()
# Out:
#   county  total_pop  siruta            uat  pop_age_18_62
# 0   Arad     174244  9262.0           ARAD       108795.0
# 1   Arad       8113  9459.0  CHISINEU-CRIS         5010.0
# 2   Arad       8848  9495.0        CURTICI         5476.0
# 3   Arad       9481  9538.0           INEU         5839.0
# 4   Arad      11096  9574.0         LIPOVA         6942.0

# %%
active_pop.info()  # There are some null values in the pop_age_18_62 columns
# There are 3181 ATUs in Romania, however this dataset contains an extra entry. We will get rid of that when we'll do the merge (inner join) with the lhdi dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3182 entries, 0 to 3181
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   county         3182 non-null   object
#  1   total_pop      3182 non-null   int64
#  2   siruta         3181 non-null   float64
#  3   uat            3182 non-null   object
#  4   pop_age_18_62  3170 non-null   float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 124.4+ KB

# %%
# Fill all null values with 0
active_pop.fillna(value=0, inplace=True)

# %%
# Check if there are any remaining null values
active_pop.isna().any()
# Out:
# county           False
# total_pop        False
# siruta           False
# uat              False
# pop_age_18_62    False
# dtype: bool

# %%
active_pop = active_pop.astype(
    {'siruta': 'int64'})  # convert to string type to be able to merge this dataframe with lhdi_2018_pred
active_pop = active_pop.astype({'siruta': 'str'})

# %%
active_pop.dtypes
# Out:
# county            object
# total_pop          int64
# siruta            object
# uat               object
# pop_age_18_62    float64
# dtype: object

# %%
# Merge the two dataframes on the siruta code
lhdi_active_pop = lhdi_2018_pred.merge(active_pop, on='siruta')
lhdi_active_pop.head()
# Out:
#                         _id  siruta  lhdi_2018_pred      county  total_pop  \
# 0  61d20d53d9221e342731f9cd  153400            41.0   Teleorman       2436
# 1  61d20d53d9221e342731f9ce  152314            40.0   Teleorman       1818
# 2  61d20d53d9221e342731f9cf  151978            57.8   Teleorman      14362
# 3  61d20d53d9221e342731f9d0  151709            39.9   Teleorman       1466
# 4  61d20d53d9221e342731f9d1  155118            50.0   Teleorman       1401
#
#           uat  pop_age_18_62
# 0   NASTURELU         1418.0
# 1      BUJORU         1018.0
# 2    ZIMNICEA         8963.0
# 3  CIUPERCENI          733.0
# 4   FANTANELE          742.0

# %%
lhdi_active_pop.shape  # check if all rows were merged
# Out:
# (3181, 7)

# %%
# In order to do the merge between the covid dataset and lhdi_active_pop we will need to aggregate all ATU data into counties, by using distinct functions on each numeric column
lhdi_active_pop_county = lhdi_active_pop.groupby('county').agg(
    {'lhdi_2018_pred': 'mean', 'total_pop': 'sum', 'pop_age_18_62': 'sum'})

# %%
lhdi_active_pop_county.head()
# Out:
#         lhdi_2018_pred  total_pop  pop_age_18_62
# county
#  Alba        52.537216     370821       230414.0
#  Arad        55.393345     467718       291486.0
#  Arges       49.758516     626489       392185.0
#  Bacau       39.872043     732530       465121.0
#  Bihor       50.479208     614001       381766.0

# %%
# As the index got the county values, we will need to reset it so that we can further use this column for the merge
lhdi_active_pop_county.reset_index(level=0, inplace=True)
lhdi_active_pop_county.head()
# Out:
#    county  lhdi_2018_pred  total_pop  pop_age_18_62
# 0    Alba       52.537216     370821       230414.0
# 1    Arad       55.393345     467718       291486.0
# 2   Arges       49.758516     626489       392185.0
# 3   Bacau       39.872043     732530       465121.0
# 4   Bihor       50.479208     614001       381766.0

# %%
lhdi_active_pop = lhdi.merge(active_pop, on='siruta')
lhdi_active_pop.shape
# Out:
# (3181, 6)

# %%
# Use the same normalization procedure on the county column of lhdi_active_pop_county so that the merge will be possible
lhdi_active_pop_county['county'] = lhdi_active_pop_county['county'].apply(lambda x: x.strip())

# %%
def normalize(x):
    if x == 'Municipiul Bucuresti':
        x = 'Bucuresti'
    return x

# %%
lhdi_active_pop_county['county'] = lhdi_active_pop_county['county'].apply(lambda x: normalize(x))
lhdi_active_pop_county.head()
# Out:
#   county  lhdi_2018_pred  total_pop  pop_age_18_62
# 0   Alba       52.537216     370821       230414.0
# 1   Arad       55.393345     467718       291486.0
# 2  Arges       49.758516     626489       392185.0
# 3  Bacau       39.872043     732530       465121.0
# 4  Bihor       50.479208     614001       381766.0

# %%
lhdi_active_pop_county_covid = lhdi_active_pop_county.merge(covid_df, on='county')
lhdi_active_pop_county_covid.shape
# Out:
# (42, 8)

# %%
lhdi_active_pop_county_covid.head()
# Out:
#   county  lhdi_2018_pred  total_pop  pop_age_18_62 code  total_county  \
# 0   Alba       52.537216     370821       230414.0   AB           671
# 1   Arad       55.393345     467718       291486.0   AR           799
# 2  Arges       49.758516     626489       392185.0   AG          2656
# 3  Bacau       39.872043     732530       465121.0   BC          1112
# 4  Bihor       50.479208     614001       381766.0   BH           836
#
#    total_healed  total_dead
# 0            27          23
# 1             1          77
# 2             0          95
# 3             0          58
# 4             0          22

# %%
lhdi_active_pop_county_covid.to_csv('Data/lhdi_active_pop_county_covid.csv', index=False)

# %%
# Get some rates (or standardize some values)
lhdi_active_pop_county_covid['death_rate'] = lhdi_active_pop_county_covid['total_dead'] / lhdi_active_pop_county_covid[
    'total_pop']
lhdi_active_pop_county_covid['infection_rate'] = lhdi_active_pop_county_covid['total_county']/lhdi_active_pop_county_covid['total_pop']
lhdi_active_pop_county_covid['healed_rate'] = lhdi_active_pop_county_covid['total_healed']/lhdi_active_pop_county_covid['total_pop']
lhdi_active_pop_county_covid['active_pop_rate'] = lhdi_active_pop_county_covid['pop_age_18_62']/lhdi_active_pop_county_covid['total_pop']
lhdi_active_pop_county_covid.head()
# Out:
#   county  lhdi_2018_pred  total_pop  pop_age_18_62 code  total_county  \
# 0   Alba       52.537216     370821       230414.0   AB           671
# 1   Arad       55.393345     467718       291486.0   AR           799
# 2  Arges       49.758516     626489       392185.0   AG          2656
# 3  Bacau       39.872043     732530       465121.0   BC          1112
# 4  Bihor       50.479208     614001       381766.0   BH           836
#
#    total_healed  total_dead  death_rate  infection_rate  healed_rate  \
# 0            27          23    0.000062        0.001809     0.000073
# 1             1          77    0.000165        0.001708     0.000002
# 2             0          95    0.000152        0.004239     0.000000
# 3             0          58    0.000079        0.001518     0.000000
# 4             0          22    0.000036        0.001362     0.000000
#
#    active_pop_rate
# 0         0.621362
# 1         0.623209
# 2         0.626005
# 3         0.634951
# 4         0.621768

# %%
# Plot some scatterplots to better understand the data
sns.scatterplot(data=lhdi_active_pop_county_covid, x="death_rate", y="infection_rate", alpha=0.2, s=70, legend=True)
# Out:
# <AxesSubplot:xlabel='death_rate', ylabel='infection_rate'>

# %%
sns.scatterplot(data=lhdi_active_pop_county_covid, x="lhdi_2018_pred", y="infection_rate", alpha=0.2, s=70, legend=True)
# Out:
# <AxesSubplot:xlabel='lhdi_2018_pred', ylabel='infection_rate'>

# %%
# Compute some logs
lhdi_active_pop_county_covid['infection_rate_log'] = np.log(lhdi_active_pop_county_covid['infection_rate'])
lhdi_active_pop_county_covid['death_rate_log'] = np.log(lhdi_active_pop_county_covid['death_rate'])
lhdi_active_pop_county_covid['healed_rate_log'] = np.log(lhdi_active_pop_county_covid['healed_rate'])
# Out:
# C:\ProgramData\Anaconda3\envs\spatial_analysis\lib\site-packages\pandas\core\arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
sns.scatterplot(data=lhdi_active_pop_county_covid, x="death_rate_log", y="infection_rate_log", alpha=0.2, s=70,
                legend=True)
# Out:
# <AxesSubplot:xlabel='death_rate_log', ylabel='infection_rate_log'>

# %%
sns.scatterplot(data=lhdi_active_pop_county_covid, x="lhdi_2018_pred", y="infection_rate_log", alpha=0.2, s=70,
                legend=True)
# Out:
# <AxesSubplot:xlabel='lhdi_2018_pred', ylabel='infection_rate_log'>

# %%
lhdi_active_pop_county_covid.head()
# Out:
#   county  lhdi_2018_pred  total_pop  pop_age_18_62 code  total_county  \
# 0   Alba       52.537216     370821       230414.0   AB           671
# 1   Arad       55.393345     467718       291486.0   AR           799
# 2  Arges       49.758516     626489       392185.0   AG          2656
# 3  Bacau       39.872043     732530       465121.0   BC          1112
# 4  Bihor       50.479208     614001       381766.0   BH           836
#
#    total_healed  total_dead
# 0            27          23
# 1             1          77
# 2             0          95
# 3             0          58
# 4             0          22

# %%
import geopandas as gpd

# Local and global Spatial Autocorrelation
from libpysal.weights.contiguity import Queen
from pysal.model import spreg

# %%
# Gather geospatial data on Romania's counties
geo_json_url = "https://raw.githubusercontent.com/geospatialorg/covid19/master/api/counties.geojson"

# %%
county_gdf = gpd.read_file(geo_json_url)
county_gdf.head(2)
# Out:
#    gid  ...                                           geometry
# 0    1  ...  POLYGON ((2755480.220 5941339.590, 2754378.160...
# 1    2  ...  POLYGON ((2580463.720 5666532.690, 2580107.500...
#
# [2 rows x 6 columns]

# %%
county_gdf.shape
# Out:
# (43, 6)

# %%
county_gdf.drop(columns=['county'], inplace=True)

# %%
county_gdf.rename(columns={'county_code': 'code'}, inplace=True)
county_gdf.head()
# Out:
#    gid code  ...         y_cen                                           geometry
# 0    1   BN  ...  5.981001e+06  POLYGON ((2755480.220 5941339.590, 2754378.160...
# 1    2   HD  ...  5.741102e+06  POLYGON ((2580463.720 5666532.690, 2580107.500...
# 2    3   BT  ...  6.083635e+06  POLYGON ((3014542.940 6021798.540, 3014787.850...
# 3    4   AR  ...  5.824345e+06  POLYGON ((2504120.810 5819440.400, 2503107.810...
# 4    5   BR  ...  5.635431e+06  POLYGON ((3043040.730 5589823.640, 3040090.770...
#
# [5 rows x 5 columns]

# %%
county_gdf.boundary.plot()

# %%
lhdi_active_pop_county_covid = county_gdf.merge(lhdi_active_pop_county_covid, on='code')
lhdi_active_pop_county_covid.shape
# Out:
# (42, 19)

# %%
lhdi_active_pop_county_covid.head()
# Out:
#    gid code         x_cen  ...  infection_rate_log death_rate_log healed_rate_log
# 0    1   BN  2.729655e+06  ...           -6.071038      -8.506775            -inf
# 1    2   HD  2.553356e+06  ...           -6.313747      -8.735349      -11.913403
# 2    3   BT  2.979024e+06  ...           -6.014696      -8.982858      -11.927297
# 3    4   AR  2.421971e+06  ...           -6.372260      -8.711815      -13.055621
# 4    5   BR  3.080402e+06  ...           -6.303325     -11.338652            -inf
#
# [5 rows x 19 columns]

# %%
plt = lhdi_active_pop_county_covid.plot(column=lhdi_active_pop_county_covid['lhdi_2018_pred'], scheme='Quantiles', k=4,
                                        cmap='OrRd', figsize=(10, 10), edgecolor='gray', linewidth=0.1, legend=True)

# %%
plt = lhdi_active_pop_county_covid.plot(column=lhdi_active_pop_county_covid['infection_rate'], scheme='Quantiles', k=4,
                                        cmap='OrRd', figsize=(10, 10), edgecolor='gray', linewidth=0.1, legend=True)

# %%
plt = lhdi_active_pop_county_covid.plot(column=lhdi_active_pop_county_covid['active_pop_rate'], scheme='Quantiles', k=4,
                                        cmap='OrRd', figsize=(10, 10), edgecolor='gray', linewidth=0.1, legend=True)

# %%
plt = lhdi_active_pop_county_covid.plot(column=lhdi_active_pop_county_covid['healed_rate'], scheme='Quantiles', k=4,
                                        cmap='OrRd', figsize=(10, 10), edgecolor='gray', linewidth=0.1, legend=True)

# %% [markdown]
# Spatial Regression

# %%
y_name = 'lhdi_2018_pred'
x_name = 'healed_rate'

# %%
y = lhdi_active_pop_county_covid[[y_name]].values
x = lhdi_active_pop_county_covid[[x_name]].values
w_q = Queen.from_dataframe(lhdi_active_pop_county_covid)
w_q.transform = 'r'
# Out:
# ('WARNING: ', 34, ' is an island (no neighbors)')

# %%
lhdi_active_pop_county_covid.loc[lhdi_active_pop_county_covid['gid'] == 34]
# Out:
#     gid code         x_cen  ...  infection_rate_log death_rate_log healed_rate_log
# 33   34   SV  2.866118e+06  ...           -5.223454      -8.056668      -11.936168
#
# [1 rows x 19 columns]

# %%
w_q.max_neighbors
# Out:
# 8

# %%
w_q.min_neighbors
# Out:
# 0

# %%
w_q.mean_neighbors
# Out:
# 4.809523809523809

# %%
# NON-SPATIAL REGRESSION - OLS ROBUST WHITE
m1_robust_white = spreg.OLS(y, x, w=w_q, spat_diag=True, name_y=y_name, name_x=[x_name], robust='white')
print(m1_robust_white.summary)
# Out:
# REGRESSION
# ----------
# SUMMARY OF OUTPUT: ORDINARY LEAST SQUARES
# -----------------------------------------
# Data set            :     unknown
# Weights matrix      :     unknown
# Dependent Variable  :lhdi_2018_pred                Number of Observations:          42
# Mean dependent var  :     48.3803                Number of Variables   :           2
# S.D. dependent var  :      9.3639                Degrees of Freedom    :          40
# R-squared           :      0.0000
# Adjusted R-squared  :     -0.0250
# Sum squared residual:    3594.956                F-statistic           :      0.0001
# Sigma-square        :      89.874                Prob(F-statistic)     :      0.9941
# S.E. of regression  :       9.480                Log likelihood        :    -153.037
# Sigma-square ML     :      85.594                Akaike info criterion :     310.075
# S.E of regression ML:      9.2517                Schwarz criterion     :     313.550
#
# White Standard Errors
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     t-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT      48.3763687       1.5933695      30.3610490       0.0000000
#          healed_rate     773.2791752    56899.9235642       0.0135902       0.9892245
# ------------------------------------------------------------------------------------
#
# REGRESSION DIAGNOSTICS
# MULTICOLLINEARITY CONDITION NUMBER            1.422
#
# TEST ON NORMALITY OF ERRORS
# TEST                             DF        VALUE           PROB
# Jarque-Bera                       2          11.100           0.0039
#
# DIAGNOSTICS FOR HETEROSKEDASTICITY
# RANDOM COEFFICIENTS
# TEST                             DF        VALUE           PROB
# Breusch-Pagan test                1           0.678           0.4104
# Koenker-Bassett test              1           0.372           0.5416
#
# DIAGNOSTICS FOR SPATIAL DEPENDENCE
# TEST                           MI/DF       VALUE           PROB
# Lagrange Multiplier (lag)         1           0.449           0.5030
# Robust LM (lag)                   1           8.415           0.0037
# Lagrange Multiplier (error)       1           6.356           0.0117
# Robust LM (error)                 1          14.322           0.0002
# Lagrange Multiplier (SARMA)       2          14.770           0.0006
#
# ================================ END OF REPORT =====================================
